# %% [markdown]
# # Coursera Capstone - Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## Part 1 - Read the data from the Toronto Open Data dataset

# %% [markdown]
# #### 1/ Imports

# %%
import pandas as pd
import numpy as np

# Import Geocoder to get each area's coordinates
#!conda install -c conda-forge geocoder             #Uncomment this if geocoder is not installed on your system
import geocoder # import geocoder

# Import k-means for clustering stage
from sklearn.cluster import KMeans

# Import Folium to draw maps
#!conda install -c conda-forge folium                #Uncomment this if folium is not installed on your system
import folium

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# Import Requests for querying FoursquareAPI
import requests

# %% [markdown]
# #### 2/ Consts and globals

# %%
# Demographic data of Toronto's areas
CONST_demographicDataLink = "https://www.toronto.ca/ext/open_data/catalog/data_set_files/2016_neighbourhood_profiles.csv"

# %% [markdown]
# FoursquareAPI credentials

# %%
CLIENT_ID = 'xxx' # your Foursquare ID
CLIENT_SECRET = 'xxx' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# Size of the radius to retrieve venues from FoursquareAPI, and limit of venues per neighbourhood
CONST_venuesRadiusScan = 1000
CONST_venuesLimit = 1000

# %% [markdown]
# #### 3/ Read the demographic data

# %%
df_raw = pd.read_csv(CONST_demographicDataLink, encoding = "cp1252", thousands=',')

# %% [markdown]
# a/ Read city areas data - Key : **CDN (Numero of area)** x **City_Area (Name of area)**

# %%
# Get only data about areas information : filter on Characteristic
df_cityAreas = df_raw[df_raw.Characteristic == "Neighbourhood Number"]

# Drop the useless columns, only keep CDN x City_Area
df_cityAreas = df_cityAreas.drop(df_cityAreas.columns[[0,1,2,3,4]], axis=1)

# Format the dataframe
df_cityAreas = df_cityAreas.transpose()
df_cityAreas = df_cityAreas.reset_index()
df_cityAreas = df_cityAreas.iloc[:, ::-1]
df_cityAreas.columns = ['CDN', 'City_Area']
df_cityAreas.head()
# Out:
#    CDN                     City_Area
# 0  129               Agincourt North
# 1  128  Agincourt South-Malvern West
# 2   20                     Alderwood
# 3   95                         Annex
# 4   42             Banbury-Don Mills

# %% [markdown]
# b/ Read demographic data by city area

# %%
# This function will count the leading space so we will know the data structure tree
def countLeadingSpaces(str):
    return len(str) - len(str.lstrip())

# %%
df_demographic = df_raw.apply(lambda x: x.str.replace(',',''))

# Filter on Topic = 'Ethnic origin population' to retrieve data about ethnic origins only
df_demographic = df_demographic[df_demographic.Topic == 'Ethnic origin population']

# Calculate the depth of Ethnic origin
df_demographic['Depth'] = df_demographic['Characteristic']

for index, row in df_demographic.iterrows():
    # The depth of Ethnic origin is calculated using the leading spaces in the data
    row['Depth'] = countLeadingSpaces(row['Depth'])

# Find each depth level of Ethnic origin, so we will be able to only keep the deepest levels
df_demographic['newLevel'] = np.where((df_demographic['Depth'].shift(+1) > df_demographic['Depth']),"new","")
    
# Reverse the dataframe
df_demographic = df_demographic.iloc[::-1]

# %% [markdown]
# Retrieve only the **deepest levels of data**
# For example, if we have the following data :
# - x Asian origins : 1,079,290
# - xxx East and Southeast Asian origins : 586,515
# - xxxxx Chinese : 332,830
# - xxxxx Japanese : 17,265
# - etc
#
# We will only keep **Chinese** and **Japanese**, because they are the deepest levels of Ethnic origin data, as they are parts of **East and Southeast Asian origins**, which is part of **Asian origins**. We don't want overlapping Ethnic origin data as they would make the clustering more difficult.

# %%
# Keep value will tell us if we need to keep the row (deepest level) or if we need to drop it
df_demographic['Keep'] = 0
tmpDepth = ""

# Loop through each row
for index, row in df_demographic.iterrows():
    # We keep the first element, because the dataframe has been reversed so the first row is a deepest level
    if tmpDepth == "":
        df_demographic.loc[index, 'Keep'] = 1
        
        # We keep the current level of depth in a temp variable, so we will be able to compare it in the next row iterration
        tmpDepth = row['Depth']
    
    else:
        # If the depth level of the previous row equals the depth level of the current row : same depth, so we keep the row
        if tmpDepth == row['Depth']:
            df_demographic.loc[index, 'Keep'] = 1
        
        # New level : we reset the temp variable
        elif row['newLevel'] == "new":
            # Reset tmpDepth
            tmpDepth = ""
            
# Reverse the dataframe
df_demographic = df_demographic.iloc[::-1]

# Keep only the necessary rows
df_demographic = df_demographic[df_demographic.Keep == 1]

# Drop the useless columns
df_demographic = df_demographic.drop(['Depth', 'newLevel', 'Keep'], 1)
df_demographic.head()
# Out:
#            Category                     Topic                     Data Source  \
# 1348  Ethnic origin  Ethnic origin population  Census Profile 98-316-X2016001
# 1349  Ethnic origin  Ethnic origin population  Census Profile 98-316-X2016001
# 1350  Ethnic origin  Ethnic origin population  Census Profile 98-316-X2016001
# 1352  Ethnic origin  Ethnic origin population  Census Profile 98-316-X2016001
# 1353  Ethnic origin  Ethnic origin population  Census Profile 98-316-X2016001
#
#                                  Characteristic City of Toronto  \
# 1348      First Nations (North American Indian)           27610
# 1349                                      Inuit             515
# 1350                                      Métis            8465
# 1352                                    Acadian            2315
# 1353                                   American           27470
#
#      Agincourt North Agincourt South-Malvern West Alderwood Annex  \
# 1348              25                           90       200   345
# 1349               0                            0        15    20
# 1350              10                           25       100   115
# 1352              20                            0        10    60
# 1353              40                           70       100   705
#
#      Banbury-Don Mills        ...         Willowdale West  \
# 1348               175        ...                      60
# 1349                10        ...                       0
# 1350                60        ...                      40
# 1352                 0        ...                       0
# 1353               325        ...                     155
#
#      Willowridge-Martingrove-Richview Woburn Woodbine Corridor  \
# 1348                              110    470               355
# 1349                                0     25                 0
# 1350                               35    110                80
# 1352                                0     10                45
# 1353                              145    140               275
#
#      Woodbine-Lumsden Wychwood Yonge-Eglinton Yonge-St.Clair  \
# 1348              235      275             90            130
# 1349                0       10              0              0
# 1350               60       80             45             75
# 1352               20       30             10              0
# 1353               95      275            320            280
#
#      York University Heights Yorkdale-Glen Park
# 1348                     200                 85
# 1349                       0                  0
# 1350                      40                 10
# 1352                      10                  0
# 1353                     175                100
#
# [5 rows x 145 columns]

# %%
# Drop the useless columns
df_demographic.drop(df_demographic.columns[[0, 1, 2, 4]], axis=1, inplace=True)
df_demographic.rename(columns={'Characteristic':''}, inplace=True)

# Put the city areas names as the dataframe columns
df_demographic = df_demographic.transpose()
df_demographic.columns = df_demographic.iloc[0]
df_demographic = df_demographic.iloc[1:]

# Drop the Total column as we won't use it
df_demographic.drop(df_demographic.columns[[0]], axis=1, inplace=True)

# Format the dataframe
df_demographic = df_demographic.reset_index()
df_demographic.rename(columns={'index':'City_Area'}, inplace=True)
df_demographic.head()
# Out:
#                       City_Area     Inuit     Métis     Acadian     American  \
# 0               Agincourt North         0        10          20           40
# 1  Agincourt South-Malvern West         0        25           0           70
# 2                     Alderwood        15       100          10          100
# 3                         Annex        20       115          60          705
# 4             Banbury-Don Mills        10        60           0          325
#
#       Canadian     New Brunswicker     Newfoundlander     Nova Scotian  \
# 0         1295                   0                 10                0
# 1         1125                   0                  0                0
# 2         2245                   0                 15                0
# 3         4655                   0                 10               10
# 4         3035                   0                  0               10
#
#       Ontarian                  ...                        Tibetan  \
# 0            0                  ...                              0
# 1            0                  ...                              0
# 2            0                  ...                            110
# 3            0                  ...                              0
# 4            0                  ...                              0
#
#         Vietnamese       East and Southeast Asian origins; n.i.e.  \
# 0              320                                             20
# 1              180                                             10
# 2               45                                              0
# 3              145                                             15
# 4              115                                              0
#
#         Other Asian origins; n.i.e.       Fijian       Hawaiian       Maori  \
# 0                               135            0              0           0
# 1                                55            0              0           0
# 2                                 0            0              0           0
# 3                                25            0              0          10
# 4                                45            0              0          10
#
#         Polynesian; n.o.s.       Samoan       Pacific Islands origins; n.i.e.
# 0                        0            0                                     0
# 1                        0            0                                     0
# 2                        0            0                                     0
# 3                        0            0                                    10
# 4                        0            0                                     0
#
# [5 rows x 252 columns]

# %% [markdown]
# ## Part 2 - Add the latitude and the longitude coordinates of each city area

# %% [markdown]
# #### 2/ Get all coordinates by postal code, using geocoder with arcgis

# %%
# This function returns the latitude and longitude of the given postal code, in Toronto
def getCoordsByCityArea(area):
    # initialize to None : this variable will allow us to loop until geocoder responds with the coordinates
    lat_lng_coords = None

    # loop until we get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(area))
        lat_lng_coords = g.latlng

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    
    return latitude, longitude

# %%
areasWithCoordsList = []

# Loop through each postal code from our dataframe
for area in df_cityAreas['City_Area']:
    # Fill the temp list with the coordinates from geocoder
    latitude, longitude = getCoordsByCityArea(area)
    areasWithCoordsList.append([area, latitude, longitude])
    
# Transform the temp list into a dataframe
df_coords = pd.DataFrame(areasWithCoordsList)
df_coords.columns = ['City_Area', 'Latitude', 'Longitude']

# Merge the coordinates dataframe with the original neighbourhoods dataframe (key : postal code)
df_cityAreas = pd.merge(df_cityAreas, df_coords, on='City_Area')
df_cityAreas.head()
# Out:
#    CDN                     City_Area  Latitude  Longitude
# 0  129               Agincourt North  43.80930  -79.26707
# 1  128  Agincourt South-Malvern West  43.78735  -79.26941
# 2   20                     Alderwood  43.60496  -79.54116
# 3   95                         Annex  43.66936  -79.40280
# 4   42             Banbury-Don Mills  43.74041  -79.34852

# %% [markdown]
# ## Part 3 - Neighbourhoods clustering using ethnic origins

# %% [markdown]
# #### 2/ Generate the map of Toronto with the neighbourhoods

# %% [markdown]
# Retrieve the coordinates of the city of Toronto so we can draw it using Folium

# %%
address = 'Toronto, ON'

# initialize to None
lat_lng_coords = None

# loop until we get the coordinates
while(lat_lng_coords is None):
    g = geocoder.arcgis('Toronto, Ontario')
    lat_lng_coords = g.latlng

latitude_toronto = lat_lng_coords[0]
longitude_toronto = lat_lng_coords[1]

print('The geographical coordinate of Toronto are {}, {}.'.format(latitude_toronto, longitude_toronto))
# Out:
# The geographical coordinate of Toronto are 43.648690000000045, -79.38543999999996.

# %% [markdown]
# We can draw the city of Toronto with the neighbourhoods from the dataframe

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=11)

# add markers to map
for lat, lng, CDN, City_Area in zip(df_cityAreas['Latitude'], df_cityAreas['Longitude'], df_cityAreas['CDN'], df_cityAreas['City_Area']):
    label = '{} - {}'.format(CDN, City_Area)
    label = folium.Popup(label, parse_html=True)

    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto) 
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Print each neighborhood along with the top 10 most common ethnic origins

# %%
num_top = 10

# Iterate through all the dataframe
for index, row in df_demographic.iterrows():
    tempArea = row['City_Area']
    
    print("----"+tempArea+"----")
    
    # Create a temp df filtered on the current neighbourhood (key : City_Area)
    temp = df_demographic[
        (df_demographic.City_Area == tempArea)
    ].T.reset_index()
    
    temp.columns = ['Origin','Count']

    # We skip the key PostalCode x Borough x Neighbourhood : length = 3, iloc[3:]
    temp = temp.iloc[1:]
    temp['Count'] = temp['Count'].astype(float)
    
    # Round the frequency with two digits
    temp = temp.round({'Count': 2})
    
    print(temp.sort_values('Count', ascending=False).reset_index(drop=True).head(num_top))
    print('\n')
# Out:
# ----Agincourt North----
#               Origin    Count
# 0            Chinese  16950.0
# 1         Sri Lankan   2230.0
# 2        East Indian   2090.0
# 3           Filipino   1465.0
# 4           Canadian   1295.0
# 5            English    870.0
# 6              Tamil    855.0
# 7           Jamaican    780.0
# 8           Scottish    600.0
# 9              Irish    425.0
#
#
# ----Agincourt South-Malvern West----
#               Origin    Count
# 0            Chinese  11455.0
# 1        East Indian   2180.0
# 2           Filipino   1405.0
# 3         Sri Lankan   1145.0
# 4           Canadian   1125.0
# 5            English    985.0
# 6           Scottish    725.0
# 7           Jamaican    645.0
# 8            Italian    630.0
# 9              Irish    620.0
#
#
# ----Alderwood----
#              Origin   Count
# 0           English  2320.0
# 1          Canadian  2245.0
# 2             Irish  1900.0
# 3          Scottish  1720.0
# 4           Italian  1275.0
# 5            Polish  1225.0
# 6            German   940.0
# 7            French   850.0
# 8         Ukrainian   810.0
# 9        Portuguese   740.0
#
#
# ----Annex----
#            Origin   Count
# 0         English  6745.0
# 1           Irish  5235.0
# 2        Scottish  5225.0
# 3        Canadian  4655.0
# 4          German  3030.0
# 5          French  2665.0
# 6          Polish  2445.0
# 7         Chinese  2400.0
# 8         Italian  2170.0
# 9         Russian  1790.0
#
#
# ----Banbury-Don Mills----
#               Origin   Count
# 0            Chinese  4850.0
# 1            English  3615.0
# 2              Irish  3075.0
# 3           Canadian  3035.0
# 4           Scottish  2835.0
# 5        East Indian  2365.0
# 6             German  1295.0
# 7           Filipino  1280.0
# 8             Polish  1225.0
# 9             French  1100.0
#
#
# ----Bathurst Manor----
#             Origin   Count
# 0         Filipino  2030.0
# 1          Russian  2005.0
# 2          Italian  1785.0
# 3           Polish  1735.0
# 4         Canadian  1500.0
# 5           Jewish  1170.0
# 6          Chinese   825.0
# 7          English   800.0
# 8        Ukrainian   795.0
# 9            Greek   645.0
#
#
# ----Bay Street Corridor----
#               Origin   Count
# 0            Chinese  7585.0
# 1            English  2800.0
# 2           Canadian  2180.0
# 3           Scottish  2090.0
# 4              Irish  1940.0
# 5        East Indian  1865.0
# 6             Korean  1370.0
# 7             German  1245.0
# 8             French  1190.0
# 9            Italian  1020.0
#
#
# ----Bayview Village----
#               Origin   Count
# 0            Chinese  6065.0
# 1            Iranian  2565.0
# 2             Korean  1685.0
# 3            English  1645.0
# 4           Canadian  1350.0
# 5              Irish  1155.0
# 6           Scottish  1135.0
# 7        East Indian  1025.0
# 8           Filipino   830.0
# 9             Polish   685.0
#
#
# ----Bayview Woods-Steeles----
#               Origin   Count
# 0            Chinese  4480.0
# 1            Iranian  1165.0
# 2            English   960.0
# 3           Canadian   830.0
# 4             Korean   730.0
# 5             Polish   675.0
# 6              Irish   645.0
# 7           Scottish   625.0
# 8            Russian   585.0
# 9        East Indian   570.0
#
#
# ----Bedford Park-Nortown----
#            Origin   Count
# 0        Canadian  4405.0
# 1          Polish  3990.0
# 2         English  3365.0
# 3         Russian  2790.0
# 4        Scottish  2400.0
# 5           Irish  2335.0
# 6        Filipino  1880.0
# 7          Jewish  1645.0
# 8          German  1610.0
# 9         Italian  1505.0
#
#
# ----Beechborough-Greenbrook----
#                                 Origin   Count
# 0                           Portuguese  1175.0
# 1                             Jamaican   775.0
# 2                              Italian   610.0
# 3                             Canadian   570.0
# 4                             Filipino   435.0
# 5                          East Indian   315.0
# 6                              English   270.0
# 7                              Spanish   265.0
# 8                           Vietnamese   230.0
# 9        Other African origins; n.i.e.   200.0
#
#
# ----Bendale----
#               Origin   Count
# 0            Chinese  4765.0
# 1        East Indian  4340.0
# 2           Filipino  3045.0
# 3           Canadian  2765.0
# 4            English  2465.0
# 5           Scottish  2035.0
# 6              Irish  1815.0
# 7         Sri Lankan  1735.0
# 8              Greek   985.0
# 9             French   785.0
#
#
# ----Birchcliffe-Cliffside----
#                                 Origin   Count
# 0                              English  6110.0
# 1                                Irish  5170.0
# 2                             Canadian  5145.0
# 3                             Scottish  4795.0
# 4                               French  1845.0
# 5                               German  1790.0
# 6                              Chinese  1490.0
# 7                              Italian  1205.0
# 8                             Filipino   910.0
# 9        British Isles origins; n.i.e.   810.0
#
#
# ----Black Creek----
#                                 Origin   Count
# 0                           Vietnamese  2300.0
# 1                             Jamaican  2050.0
# 2                             Canadian  1760.0
# 3                              Italian  1565.0
# 4                          East Indian  1505.0
# 5                              Chinese  1375.0
# 6                             Filipino   980.0
# 7                                Iraqi   920.0
# 8                             Ghanaian   870.0
# 9        Other African origins; n.i.e.   830.0
#
#
# ----Blake-Jones----
#               Origin   Count
# 0            English  1700.0
# 1           Canadian  1580.0
# 2              Irish  1450.0
# 3           Scottish  1295.0
# 4            Chinese  1035.0
# 5             French   730.0
# 6             German   590.0
# 7              Greek   450.0
# 8        East Indian   355.0
# 9           Jamaican   280.0
#
#
# ----Briar Hill-Belgravia----
#              Origin   Count
# 0          Filipino  3135.0
# 1           Italian  1655.0
# 2        Portuguese  1605.0
# 3          Canadian  1100.0
# 4           English   760.0
# 5          Scottish   695.0
# 6             Irish   625.0
# 7          Albanian   600.0
# 8           Russian   535.0
# 9            Polish   510.0
#
#
# ----Bridle Path-Sunnybrook-York Mills----
#            Origin   Count
# 0         English  1960.0
# 1        Scottish  1530.0
# 2        Canadian  1465.0
# 3         Chinese  1445.0
# 4           Irish  1440.0
# 5         Italian   740.0
# 6          German   725.0
# 7          French   645.0
# 8         Russian   550.0
# 9          Polish   510.0
#
#
# ----Broadview North----
#            Origin   Count
# 0         English  1980.0
# 1           Irish  1675.0
# 2        Scottish  1580.0
# 3           Greek  1560.0
# 4        Canadian  1480.0
# 5          French   885.0
# 6          German   820.0
# 7         Chinese   585.0
# 8        Filipino   575.0
# 9         Serbian   545.0
#
#
# ----Brookhaven-Amesbury----
#                                 Origin   Count
# 0                              Italian  1985.0
# 1                           Portuguese  1780.0
# 2                             Jamaican  1640.0
# 3                             Canadian  1495.0
# 4                             Filipino  1330.0
# 5                           Vietnamese  1115.0
# 6                              Chinese   900.0
# 7        Other African origins; n.i.e.   865.0
# 8                              English   745.0
# 9                          East Indian   720.0
#
#
# ----Cabbagetown-South St. James Town----
#                                 Origin   Count
# 0                              English  2855.0
# 1                                Irish  2435.0
# 2                             Scottish  2305.0
# 3                             Canadian  1870.0
# 4                               German  1280.0
# 5                               French  1160.0
# 6                              Chinese   855.0
# 7                              Italian   605.0
# 8        British Isles origins; n.i.e.   515.0
# 9                               Polish   510.0
#
#
# ----Caledonia-Fairbank----
#              Origin   Count
# 0        Portuguese  3560.0
# 1           Italian  1270.0
# 2          Canadian   915.0
# 3          Filipino   885.0
# 4           English   495.0
# 5             Irish   425.0
# 6           Spanish   405.0
# 7          Scottish   385.0
# 8           Chinese   325.0
# 9            French   315.0
#
#
# ----Casa Loma----
#            Origin   Count
# 0         English  2505.0
# 1           Irish  2185.0
# 2        Scottish  2105.0
# 3        Canadian  2055.0
# 4          Polish  1510.0
# 5         Russian  1095.0
# 6          German  1085.0
# 7          French   890.0
# 8         Italian   705.0
# 9          Jewish   670.0
#
#
# ----Centennial Scarborough----
#               Origin   Count
# 0            English  2540.0
# 1           Canadian  2355.0
# 2           Scottish  1925.0
# 3              Irish  1820.0
# 4        East Indian  1420.0
# 5            Chinese   975.0
# 6            Italian   900.0
# 7             German   885.0
# 8           Filipino   855.0
# 9             French   700.0
#
#
# ----Church-Yonge Corridor----
#               Origin   Count
# 0            English  5255.0
# 1              Irish  4705.0
# 2           Scottish  4325.0
# 3            Chinese  4305.0
# 4           Canadian  4180.0
# 5             French  2390.0
# 6             German  2315.0
# 7        East Indian  2045.0
# 8            Italian  1665.0
# 9             Polish  1530.0
#
#
# ----Clairlea-Birchmount----
#               Origin   Count
# 0           Canadian  4125.0
# 1           Filipino  3250.0
# 2            English  2810.0
# 3            Chinese  2440.0
# 4        East Indian  2185.0
# 5              Irish  2115.0
# 6           Scottish  2010.0
# 7        Bangladeshi  1390.0
# 8            Italian  1210.0
# 9              Greek   980.0
#
#
# ----Clanton Park----
#             Origin   Count
# 0         Filipino  3505.0
# 1           Polish  2135.0
# 2         Canadian  1980.0
# 3          Italian  1705.0
# 4          Russian  1590.0
# 5           Jewish  1235.0
# 6          English   935.0
# 7          Chinese   835.0
# 8        Hungarian   635.0
# 9           German   635.0
#
#
# ----Cliffcrest----
#               Origin   Count
# 0            English  3225.0
# 1           Canadian  3080.0
# 2           Scottish  2685.0
# 3              Irish  2625.0
# 4        East Indian  1240.0
# 5            Chinese  1040.0
# 6             German  1025.0
# 7             French   965.0
# 8            Italian   905.0
# 9           Filipino   805.0
#
#
# ----Corso Italia-Davenport----
#              Origin   Count
# 0        Portuguese  3690.0
# 1           Italian  2920.0
# 2          Canadian  1640.0
# 3           English  1595.0
# 4             Irish  1450.0
# 5          Scottish  1245.0
# 6            French   845.0
# 7            German   800.0
# 8           Spanish   530.0
# 9           Chinese   520.0
#
#
# ----Danforth----
#               Origin   Count
# 0            English  2305.0
# 1           Canadian  1935.0
# 2              Irish  1865.0
# 3           Scottish  1765.0
# 4            Italian  1160.0
# 5            Chinese   925.0
# 6             German   885.0
# 7             French   840.0
# 8              Greek   810.0
# 9        East Indian   595.0
#
#
# ----Danforth East York----
#               Origin   Count
# 0            English  3625.0
# 1              Irish  3080.0
# 2           Canadian  2965.0
# 3           Scottish  2840.0
# 4              Greek  2195.0
# 5            Chinese  1760.0
# 6             German  1510.0
# 7            Italian  1415.0
# 8             French  1365.0
# 9        East Indian   785.0
#
#
# ----Don Valley Village----
#               Origin   Count
# 0            Chinese  7390.0
# 1           Filipino  2245.0
# 2        East Indian  2135.0
# 3            Iranian  2100.0
# 4            English  1545.0
# 5           Canadian  1480.0
# 6              Irish  1095.0
# 7           Scottish  1040.0
# 8             Korean   875.0
# 9           Armenian   730.0
#
#
# ----Dorset Park----
#               Origin   Count
# 0           Filipino  3660.0
# 1        East Indian  3355.0
# 2            Chinese  3115.0
# 3           Canadian  2505.0
# 4         Sri Lankan  2305.0
# 5            English  1365.0
# 6           Jamaican   965.0
# 7           Scottish   960.0
# 8              Tamil   910.0
# 9              Irish   880.0
#
#
# ----Dovercourt-Wallace Emerson-Junction----
#               Origin   Count
# 0         Portuguese  7360.0
# 1            English  5510.0
# 2           Canadian  4600.0
# 3              Irish  4560.0
# 4           Scottish  4295.0
# 5            Chinese  3315.0
# 6            Italian  3155.0
# 7             German  2275.0
# 8             French  2205.0
# 9        East Indian  1485.0
#
#
# ----Downsview-Roding-CFB----
#               Origin   Count
# 0            Italian  8205.0
# 1           Filipino  4790.0
# 2           Canadian  2515.0
# 3           Jamaican  2350.0
# 4         Vietnamese  1950.0
# 5         Portuguese  1820.0
# 6            Chinese  1650.0
# 7            English  1535.0
# 8            Spanish  1490.0
# 9        East Indian  1265.0
#
#
# ----Dufferin Grove----
#              Origin   Count
# 0        Portuguese  2215.0
# 1           English  1875.0
# 2          Scottish  1720.0
# 3          Canadian  1695.0
# 4             Irish  1605.0
# 5           Chinese   920.0
# 6            French   910.0
# 7            German   800.0
# 8           Italian   740.0
# 9            Polish   675.0
#
#
# ----East End-Danforth----
#            Origin   Count
# 0         English  5915.0
# 1           Irish  4915.0
# 2        Scottish  4495.0
# 3        Canadian  4240.0
# 4          French  2065.0
# 5          German  2055.0
# 6         Chinese  1495.0
# 7         Italian  1275.0
# 8          Polish   890.0
# 9        Filipino   795.0
#
#
# ----Edenbridge-Humber Valley----
#              Origin   Count
# 0           Italian  2590.0
# 1           English  2280.0
# 2             Irish  1970.0
# 3          Canadian  1915.0
# 4          Scottish  1795.0
# 5         Ukrainian  1555.0
# 6            Polish  1150.0
# 7            German   980.0
# 8            French   785.0
# 9        Portuguese   595.0
#
#
# ----Eglinton East----
#               Origin   Count
# 0           Filipino  3110.0
# 1        East Indian  2860.0
# 2           Canadian  2590.0
# 3         Sri Lankan  2185.0
# 4           Jamaican  1450.0
# 5            English  1445.0
# 6            Chinese  1230.0
# 7           Scottish   965.0
# 8              Irish   945.0
# 9              Tamil   910.0
#
#
# ----Elms-Old Rexdale----
#                                 Origin   Count
# 0                             Canadian  1100.0
# 1                               Somali  1015.0
# 2                              Italian   880.0
# 3                             Jamaican   725.0
# 4                              English   650.0
# 5                          East Indian   570.0
# 6                             Filipino   570.0
# 7                             Scottish   565.0
# 8                                Irish   505.0
# 9        Other African origins; n.i.e.   365.0
#
#
# ----Englemount-Lawrence----
#             Origin   Count
# 0         Filipino  4090.0
# 1           Polish  3665.0
# 2         Canadian  2595.0
# 3          Russian  2010.0
# 4           Jewish  1830.0
# 5        Hungarian  1480.0
# 6          English  1215.0
# 7          Italian  1195.0
# 8           German  1150.0
# 9         American   830.0
#
#
# ----Eringate-Centennial-West Deane----
#              Origin   Count
# 0          Canadian  2715.0
# 1           English  2685.0
# 2           Italian  2135.0
# 3             Irish  2000.0
# 4          Scottish  1830.0
# 5         Ukrainian  1560.0
# 6            Polish  1480.0
# 7            German  1040.0
# 8           Chinese   970.0
# 9        Portuguese   930.0
#
#
# ----Etobicoke West Mall----
#               Origin   Count
# 0            English  1295.0
# 1           Canadian  1200.0
# 2           Scottish   920.0
# 3              Irish   910.0
# 4          Ukrainian   875.0
# 5             Polish   795.0
# 6            Italian   740.0
# 7           Filipino   715.0
# 8        East Indian   620.0
# 9            Serbian   580.0
#
#
# ----Flemingdon Park----
#               Origin   Count
# 0        East Indian  4420.0
# 1           Filipino  2370.0
# 2             Afghan  1855.0
# 3          Pakistani  1370.0
# 4            Chinese  1285.0
# 5           Canadian  1250.0
# 6              Greek   830.0
# 7            English   790.0
# 8         Sri Lankan   630.0
# 9             Slovak   565.0
#
#
# ----Forest Hill North----
#            Origin   Count
# 0          Polish  2700.0
# 1         Russian  2085.0
# 2        Canadian  1735.0
# 3        Filipino  1580.0
# 4         English  1215.0
# 5          Jewish  1200.0
# 6        Scottish   835.0
# 7           Irish   820.0
# 8        Romanian   655.0
# 9          German   575.0
#
#
# ----Forest Hill South----
#            Origin   Count
# 0          Polish  2325.0
# 1        Canadian  1995.0
# 2         Russian  1740.0
# 3         English  1510.0
# 4        Scottish  1205.0
# 5           Irish  1170.0
# 6          Jewish   865.0
# 7          German   835.0
# 8          French   690.0
# 9         Chinese   560.0
#
#
# ----Glenfield-Jane Heights----
#               Origin   Count
# 0            Italian  4310.0
# 1         Vietnamese  3585.0
# 2           Jamaican  2870.0
# 3            Chinese  2260.0
# 4        East Indian  1965.0
# 5           Canadian  1850.0
# 6           Filipino  1675.0
# 7            Spanish  1265.0
# 8           Guyanese  1010.0
# 9            English   955.0
#
#
# ----Greenwood-Coxwell----
#               Origin   Count
# 0            English  3415.0
# 1           Canadian  2970.0
# 2              Irish  2965.0
# 3           Scottish  2635.0
# 4            Chinese  2365.0
# 5             French  1460.0
# 6             German  1330.0
# 7            Italian   840.0
# 8             Polish   665.0
# 9        East Indian   630.0
#
#
# ----Guildwood----
#               Origin   Count
# 0            English  2600.0
# 1              Irish  1985.0
# 2           Scottish  1975.0
# 3           Canadian  1770.0
# 4             German   935.0
# 5             French   725.0
# 6        East Indian   660.0
# 7            Italian   545.0
# 8           Filipino   505.0
# 9            Chinese   420.0
#
#
# ----Henry Farm----
#               Origin   Count
# 0            Chinese  3365.0
# 1        East Indian  2290.0
# 2           Filipino  1380.0
# 3            Iranian   860.0
# 4           Canadian   855.0
# 5            English   830.0
# 6           Scottish   685.0
# 7              Irish   605.0
# 8             Afghan   460.0
# 9             Korean   455.0
#
#
# ----High Park North----
#             Origin   Count
# 0          English  4385.0
# 1            Irish  3860.0
# 2         Scottish  3730.0
# 3         Canadian  3345.0
# 4           German  2265.0
# 5           Polish  2005.0
# 6           French  1875.0
# 7        Ukrainian  1645.0
# 8          Italian  1320.0
# 9          Russian  1205.0
#
#
# ----High Park-Swansea----
#                                 Origin   Count
# 0                              English  6115.0
# 1                                Irish  5265.0
# 2                             Scottish  4970.0
# 3                             Canadian  3710.0
# 4                               German  2365.0
# 5                               Polish  2250.0
# 6                               French  2135.0
# 7                              Italian  1785.0
# 8                            Ukrainian  1760.0
# 9        British Isles origins; n.i.e.   970.0
#
#
# ----Highland Creek----
#               Origin   Count
# 0        East Indian  2595.0
# 1         Sri Lankan  1445.0
# 2            Chinese  1195.0
# 3           Canadian  1160.0
# 4           Filipino   880.0
# 5            English   870.0
# 6           Jamaican   850.0
# 7              Irish   675.0
# 8            Italian   665.0
# 9           Scottish   660.0
#
#
# ----Hillcrest Village----
#               Origin   Count
# 0            Chinese  8265.0
# 1        East Indian  1060.0
# 2           Canadian   915.0
# 3            Iranian   775.0
# 4             Korean   695.0
# 5            English   690.0
# 6            Russian   555.0
# 7           Scottish   545.0
# 8             Polish   530.0
# 9              Irish   490.0
#
#
# ----Humber Heights-Westmount----
#              Origin   Count
# 0           Italian  2295.0
# 1         Ukrainian   990.0
# 2          Canadian   885.0
# 3           English   880.0
# 4             Irish   825.0
# 5        Portuguese   775.0
# 6          Scottish   765.0
# 7            Polish   625.0
# 8            German   405.0
# 9           Spanish   360.0
#
#
# ----Humber Summit----
#               Origin   Count
# 0            Italian  2970.0
# 1        East Indian  1990.0
# 2          Pakistani  1005.0
# 3           Jamaican   975.0
# 4           Canadian   965.0
# 5         Vietnamese   450.0
# 6              Iraqi   380.0
# 7           Filipino   365.0
# 8            English   325.0
# 9            Spanish   315.0
#
#
# ----Humbermede----
#               Origin   Count
# 0        East Indian  2245.0
# 1            Italian  1620.0
# 2           Canadian  1285.0
# 3           Jamaican  1230.0
# 4         Vietnamese  1000.0
# 5           Filipino   920.0
# 6          Pakistani   850.0
# 7            Chinese   655.0
# 8            Spanish   655.0
# 9            English   630.0
#
#
# ----Humewood-Cedarvale----
#            Origin   Count
# 0        Canadian  2430.0
# 1         English  2185.0
# 2          Polish  1985.0
# 3        Scottish  1785.0
# 4           Irish  1780.0
# 5        Filipino  1540.0
# 6         Russian  1485.0
# 7          German  1180.0
# 8         Italian  1110.0
# 9          Jewish   910.0
#
#
# ----Ionview----
#               Origin   Count
# 0           Filipino  2535.0
# 1        East Indian  2025.0
# 2           Canadian  1345.0
# 3            English  1000.0
# 4            Chinese   855.0
# 5         Sri Lankan   845.0
# 6              Irish   750.0
# 7           Scottish   745.0
# 8           Jamaican   600.0
# 9              Greek   495.0
#
#
# ----Islington-City Centre West----
#               Origin   Count
# 0            English  5045.0
# 1           Canadian  4630.0
# 2            Italian  4195.0
# 3              Irish  4160.0
# 4           Scottish  4015.0
# 5             Polish  3240.0
# 6          Ukrainian  3165.0
# 7        East Indian  2585.0
# 8             German  2330.0
# 9            Chinese  2250.0
#
#
# ----Junction Area----
#              Origin   Count
# 0           English  2970.0
# 1             Irish  2705.0
# 2          Scottish  2500.0
# 3          Canadian  2205.0
# 4            German  1430.0
# 5            French  1215.0
# 6        Portuguese  1140.0
# 7           Chinese  1110.0
# 8           Italian  1015.0
# 9            Polish   790.0
#
#
# ----Keelesdale-Eglinton West----
#               Origin   Count
# 0         Portuguese  3925.0
# 1            Italian  1060.0
# 2           Filipino   850.0
# 3        East Indian   815.0
# 4           Canadian   740.0
# 5           Jamaican   550.0
# 6            English   480.0
# 7            Spanish   460.0
# 8              Irish   330.0
# 9           Scottish   320.0
#
#
# ----Kennedy Park----
#               Origin   Count
# 0           Filipino  2750.0
# 1           Canadian  2070.0
# 2        East Indian  1555.0
# 3            English  1435.0
# 4            Chinese  1240.0
# 5              Irish  1085.0
# 6           Scottish   910.0
# 7         Sri Lankan   905.0
# 8        Bangladeshi   850.0
# 9           Jamaican   815.0
#
#
# ----Kensington-Chinatown----
#            Origin   Count
# 0         Chinese  6250.0
# 1        Canadian  2090.0
# 2         English  2055.0
# 3           Irish  1805.0
# 4        Scottish  1760.0
# 5          French   995.0
# 6          German   900.0
# 7         Italian   585.0
# 8          Polish   565.0
# 9        Filipino   470.0
#
#
# ----Kingsview Village-The Westway----
#               Origin   Count
# 0             Somali  2815.0
# 1            Italian  2730.0
# 2        East Indian  2065.0
# 3           Canadian  1745.0
# 4            English  1610.0
# 5           Jamaican  1235.0
# 6           Scottish  1050.0
# 7              Irish  1015.0
# 8          Pakistani   845.0
# 9         Portuguese   780.0
#
#
# ----Kingsway South----
#                                 Origin   Count
# 0                              English  2720.0
# 1                                Irish  2115.0
# 2                             Canadian  1990.0
# 3                             Scottish  1955.0
# 4                              Italian  1075.0
# 5                               German   965.0
# 6                               French   865.0
# 7                               Polish   715.0
# 8                            Ukrainian   650.0
# 9        British Isles origins; n.i.e.   415.0
#
#
# ----Lambton Baby Point----
#              Origin   Count
# 0           English  1840.0
# 1          Scottish  1610.0
# 2             Irish  1505.0
# 3          Canadian  1250.0
# 4            German   760.0
# 5            Polish   735.0
# 6         Ukrainian   730.0
# 7           Italian   615.0
# 8            French   595.0
# 9        Portuguese   350.0
#
#
# ----L'Amoreaux----
#               Origin    Count
# 0            Chinese  16745.0
# 1        East Indian   3395.0
# 2           Canadian   2695.0
# 3         Sri Lankan   2660.0
# 4           Filipino   2545.0
# 5            English   2180.0
# 6           Armenian   1990.0
# 7           Jamaican   1595.0
# 8           Scottish   1435.0
# 9              Irish   1305.0
#
#
# ----Lansing-Westgate----
#               Origin   Count
# 0           Canadian  1920.0
# 1            Chinese  1910.0
# 2            English  1640.0
# 3             Polish  1625.0
# 4            Russian  1540.0
# 5              Irish  1195.0
# 6           Scottish  1130.0
# 7           Filipino  1120.0
# 8            Iranian  1105.0
# 9        East Indian   960.0
#
#
# ----Lawrence Park North----
#            Origin   Count
# 0         English  4340.0
# 1        Scottish  3545.0
# 2        Canadian  3385.0
# 3           Irish  3215.0
# 4          German  1505.0
# 5         Chinese  1390.0
# 6          French  1130.0
# 7          Polish  1030.0
# 8         Italian   975.0
# 9         Russian   710.0
#
#
# ----Lawrence Park South----
#            Origin   Count
# 0         English  4260.0
# 1        Scottish  3630.0
# 2        Canadian  3500.0
# 3           Irish  3165.0
# 4          German  1570.0
# 5          Polish  1545.0
# 6         Russian  1255.0
# 7          French  1220.0
# 8         Italian  1035.0
# 9         Chinese   935.0
#
#
# ----Leaside-Bennington----
#                                 Origin   Count
# 0                              English  5605.0
# 1                             Scottish  4565.0
# 2                                Irish  4185.0
# 3                             Canadian  3815.0
# 4                               German  1745.0
# 5                               French  1390.0
# 6                              Italian  1230.0
# 7                              Chinese  1125.0
# 8        British Isles origins; n.i.e.   910.0
# 9                               Polish   660.0
#
#
# ----Little Portugal----
#              Origin   Count
# 0        Portuguese  3000.0
# 1           English  2555.0
# 2          Canadian  2385.0
# 3             Irish  2310.0
# 4          Scottish  2195.0
# 5           Chinese  1605.0
# 6            French  1190.0
# 7           Italian  1115.0
# 8            German  1105.0
# 9            Polish   715.0
#
#
# ----Long Branch----
#             Origin   Count
# 0         Canadian  2105.0
# 1          English  1870.0
# 2            Irish  1760.0
# 3         Scottish  1500.0
# 4           Polish  1180.0
# 5           German   890.0
# 6        Ukrainian   825.0
# 7           French   760.0
# 8          Italian   575.0
# 9         Filipino   425.0
#
#
# ----Malvern----
#               Origin   Count
# 0        East Indian  9325.0
# 1         Sri Lankan  5225.0
# 2           Filipino  5095.0
# 3            Chinese  4215.0
# 4           Jamaican  4065.0
# 5           Canadian  3620.0
# 6            English  2005.0
# 7              Tamil  1930.0
# 8           Guyanese  1440.0
# 9          Pakistani  1415.0
#
#
# ----Maple Leaf----
#               Origin   Count
# 0            Italian  3550.0
# 1           Filipino  1220.0
# 2         Portuguese   970.0
# 3        East Indian   850.0
# 4           Canadian   560.0
# 5            English   385.0
# 6           Jamaican   375.0
# 7         Vietnamese   310.0
# 8            Chinese   260.0
# 9              Irish   250.0
#
#
# ----Markland Wood----
#             Origin   Count
# 0          English  2190.0
# 1         Scottish  1645.0
# 2            Irish  1635.0
# 3         Canadian  1520.0
# 4        Ukrainian  1000.0
# 5          Italian   905.0
# 6           Polish   895.0
# 7          Serbian   890.0
# 8           German   710.0
# 9           French   575.0
#
#
# ----Milliken----
#               Origin    Count
# 0            Chinese  19140.0
# 1         Sri Lankan   1330.0
# 2        East Indian   1310.0
# 3           Filipino   1135.0
# 4           Canadian   1010.0
# 5              Tamil    590.0
# 6           Jamaican    575.0
# 7            English    400.0
# 8         Vietnamese    260.0
# 9            Spanish    225.0
#
#
# ----Mimico (includes Humber Bay Shores)----
#             Origin   Count
# 0          English  5410.0
# 1         Canadian  4985.0
# 2            Irish  4235.0
# 3         Scottish  4120.0
# 4          Italian  2945.0
# 5           Polish  2780.0
# 6        Ukrainian  2350.0
# 7           German  2200.0
# 8           French  2185.0
# 9          Chinese  2010.0
#
#
# ----Morningside----
#               Origin   Count
# 0        East Indian  2570.0
# 1           Canadian  2285.0
# 2           Filipino  1965.0
# 3         Sri Lankan  1775.0
# 4            English  1530.0
# 5           Jamaican  1495.0
# 6            Chinese  1330.0
# 7           Scottish  1040.0
# 8              Irish   865.0
# 9             French   510.0
#
#
# ----Moss Park----
#               Origin   Count
# 0            English  3325.0
# 1           Canadian  3050.0
# 2              Irish  2755.0
# 3           Scottish  2660.0
# 4            Chinese  1650.0
# 5             French  1515.0
# 6             German  1395.0
# 7            Italian  1090.0
# 8        East Indian   855.0
# 9             Polish   740.0
#
#
# ----Mount Dennis----
#                                 Origin   Count
# 0                             Jamaican  1510.0
# 1                           Portuguese  1465.0
# 2                             Canadian  1415.0
# 3                             Filipino   840.0
# 4                              English   765.0
# 5                              Italian   670.0
# 6                           Vietnamese   650.0
# 7                                Irish   530.0
# 8        Other African origins; n.i.e.   500.0
# 9                             Scottish   495.0
#
#
# ----Mount Olive-Silverstone-Jamestown----
#                                 Origin   Count
# 0                          East Indian  8540.0
# 1                                Iraqi  3135.0
# 2                             Jamaican  2465.0
# 3                             Canadian  2200.0
# 4                               Somali  1225.0
# 5                              Italian  1145.0
# 6                             Assyrian  1145.0
# 7                           Sri Lankan  1130.0
# 8        Other African origins; n.i.e.  1105.0
# 9                             Ghanaian   930.0
#
#
# ----Mount Pleasant East----
#            Origin   Count
# 0         English  4580.0
# 1           Irish  3510.0
# 2        Scottish  3455.0
# 3        Canadian  3385.0
# 4          German  1710.0
# 5          French  1435.0
# 6          Polish  1225.0
# 7         Chinese  1095.0
# 8         Italian  1080.0
# 9         Russian   860.0
#
#
# ----Mount Pleasant West----
#               Origin   Count
# 0            English  5435.0
# 1           Scottish  4350.0
# 2           Canadian  4340.0
# 3              Irish  4320.0
# 4             German  2085.0
# 5             French  2025.0
# 6             Polish  1940.0
# 7            Russian  1745.0
# 8        East Indian  1695.0
# 9            Chinese  1675.0
#
#
# ----New Toronto----
#               Origin   Count
# 0           Canadian  2145.0
# 1            English  2020.0
# 2           Scottish  1770.0
# 3              Irish  1770.0
# 4             Polish  1100.0
# 5             French   900.0
# 6             German   840.0
# 7          Ukrainian   690.0
# 8            Italian   610.0
# 9        East Indian   510.0
#
#
# ----Newtonbrook East----
#               Origin   Count
# 0            Chinese  4765.0
# 1            Iranian  2530.0
# 2             Korean  1960.0
# 3            English   940.0
# 4           Canadian   815.0
# 5              Irish   805.0
# 6           Scottish   680.0
# 7            Italian   670.0
# 8        East Indian   580.0
# 9           Filipino   515.0
#
#
# ----Newtonbrook West----
#             Origin   Count
# 0         Filipino  4475.0
# 1          Chinese  2785.0
# 2          Russian  2410.0
# 3           Korean  2275.0
# 4          Iranian  1935.0
# 5           Jewish  1295.0
# 6          Italian  1255.0
# 7        Ukrainian  1190.0
# 8          English  1185.0
# 9         Canadian  1145.0
#
#
# ----Niagara----
#               Origin   Count
# 0            English  5710.0
# 1              Irish  4940.0
# 2           Canadian  4860.0
# 3           Scottish  4630.0
# 4             German  2885.0
# 5            Chinese  2720.0
# 6            Italian  2575.0
# 7             French  2440.0
# 8        East Indian  1975.0
# 9             Polish  1720.0
#
#
# ----North Riverdale----
#            Origin   Count
# 0         English  3680.0
# 1        Scottish  2885.0
# 2           Irish  2790.0
# 3        Canadian  2170.0
# 4         Chinese  1385.0
# 5          German  1380.0
# 6          French  1100.0
# 7          Polish   695.0
# 8           Greek   655.0
# 9         Italian   625.0
#
#
# ----North St. James Town----
#               Origin   Count
# 0           Filipino  2910.0
# 1           Canadian  1875.0
# 2            English  1815.0
# 3        East Indian  1700.0
# 4              Irish  1475.0
# 5           Scottish  1425.0
# 6            Chinese  1115.0
# 7             French   895.0
# 8             German   790.0
# 9          Ethiopian   630.0
#
#
# ----Oakridge----
#                               Origin   Count
# 0                        Bangladeshi  1900.0
# 1                           Canadian  1585.0
# 2                        East Indian  1145.0
# 3                            English   955.0
# 4                            Chinese   825.0
# 5                            Bengali   790.0
# 6                              Irish   775.0
# 7                           Filipino   700.0
# 8                           Scottish   670.0
# 9        South Asian origins; n.i.e.   555.0
#
#
# ----Oakwood Village----
#              Origin   Count
# 0           Italian  3145.0
# 1          Canadian  2495.0
# 2        Portuguese  2415.0
# 3           English  2155.0
# 4          Filipino  1985.0
# 5             Irish  1760.0
# 6          Scottish  1550.0
# 7           Chinese  1140.0
# 8          Jamaican  1040.0
# 9            Polish   965.0
#
#
# ----O'Connor-Parkview----
#            Origin   Count
# 0        Canadian  3365.0
# 1         English  2740.0
# 2           Irish  2480.0
# 3        Scottish  2430.0
# 4           Greek  2160.0
# 5        Filipino  1190.0
# 6          French  1110.0
# 7         Italian  1080.0
# 8          German   955.0
# 9         Chinese   880.0
#
#
# ----Old East York----
#            Origin   Count
# 0         English  1860.0
# 1           Irish  1660.0
# 2        Canadian  1640.0
# 3           Greek  1555.0
# 4        Scottish  1440.0
# 5         Chinese   840.0
# 6          French   680.0
# 7         Italian   655.0
# 8          German   625.0
# 9        Filipino   465.0
#
#
# ----Palmerston-Little Italy----
#              Origin   Count
# 0           English  3100.0
# 1             Irish  2730.0
# 2          Scottish  2535.0
# 3          Canadian  2415.0
# 4           Italian  1620.0
# 5            German  1420.0
# 6        Portuguese  1380.0
# 7           Chinese  1260.0
# 8            French  1230.0
# 9            Polish  1080.0
#
#
# ----Parkwoods-Donalda----
#               Origin   Count
# 0           Canadian  4205.0
# 1            English  3965.0
# 2            Chinese  3475.0
# 3           Scottish  3235.0
# 4              Irish  3090.0
# 5           Filipino  2515.0
# 6        East Indian  2165.0
# 7             German  1730.0
# 8           Jamaican  1620.0
# 9             French  1490.0
#
#
# ----Pelmo Park-Humberlea----
#               Origin   Count
# 0            Italian  2855.0
# 1           Canadian  1085.0
# 2         Portuguese   925.0
# 3         Vietnamese   785.0
# 4            English   745.0
# 5           Jamaican   560.0
# 6           Scottish   525.0
# 7           Filipino   520.0
# 8            Chinese   445.0
# 9        East Indian   410.0
#
#
# ----Playter Estates-Danforth----
#            Origin   Count
# 0         English  2320.0
# 1        Scottish  1970.0
# 2           Irish  1780.0
# 3        Canadian  1425.0
# 4          German   915.0
# 5          French   765.0
# 6           Greek   735.0
# 7         Chinese   550.0
# 8          Polish   380.0
# 9         Italian   370.0
#
#
# ----Pleasant View----
#               Origin   Count
# 0            Chinese  5795.0
# 1              Greek  1265.0
# 2            Italian  1220.0
# 3           Canadian  1040.0
# 4        East Indian   905.0
# 5            English   800.0
# 6           Scottish   745.0
# 7           Filipino   685.0
# 8              Irish   595.0
# 9            Iranian   470.0
#
#
# ----Princess-Rosethorn----
#              Origin   Count
# 0           English  2380.0
# 1           Italian  1960.0
# 2             Irish  1655.0
# 3          Canadian  1580.0
# 4          Scottish  1535.0
# 5            Polish   970.0
# 6         Ukrainian   805.0
# 7            German   780.0
# 8           Chinese   545.0
# 9        Portuguese   525.0
#
#
# ----Regent Park----
#               Origin   Count
# 0            Chinese  1530.0
# 1           Canadian  1380.0
# 2              Irish   935.0
# 3            English   875.0
# 4        Bangladeshi   810.0
# 5        East Indian   760.0
# 6           Scottish   705.0
# 7             French   525.0
# 8         Sri Lankan   475.0
# 9            Bengali   455.0
#
#
# ----Rexdale-Kipling----
#               Origin   Count
# 0           Canadian  1260.0
# 1            Italian  1135.0
# 2            English  1120.0
# 3        East Indian  1015.0
# 4           Scottish   900.0
# 5              Irish   855.0
# 6           Jamaican   585.0
# 7           Filipino   575.0
# 8             German   460.0
# 9            Spanish   415.0
#
#
# ----Rockcliffe-Smythe----
#              Origin   Count
# 0        Portuguese  4335.0
# 1          Canadian  2100.0
# 2           English  1910.0
# 3           Italian  1560.0
# 4             Irish  1380.0
# 5          Scottish  1255.0
# 6        Vietnamese  1240.0
# 7          Jamaican  1155.0
# 8          Filipino   855.0
# 9           Chinese   825.0
#
#
# ----Roncesvalles----
#              Origin   Count
# 0           English  3455.0
# 1             Irish  3215.0
# 2          Scottish  2935.0
# 3          Canadian  2765.0
# 4            French  1450.0
# 5            German  1375.0
# 6            Polish  1365.0
# 7           Italian   965.0
# 8        Portuguese   770.0
# 9         Ukrainian   740.0
#
#
# ----Rosedale-Moore Park----
#                                 Origin   Count
# 0                              English  6280.0
# 1                             Scottish  5060.0
# 2                                Irish  4785.0
# 3                             Canadian  4045.0
# 4                               German  2065.0
# 5                               French  1910.0
# 6                              Chinese  1300.0
# 7                               Polish  1260.0
# 8                              Italian  1070.0
# 9        British Isles origins; n.i.e.   920.0
#
#
# ----Rouge----
#               Origin   Count
# 0        East Indian  8645.0
# 1         Sri Lankan  8400.0
# 2           Canadian  4665.0
# 3           Filipino  4365.0
# 4           Jamaican  3610.0
# 5            English  3340.0
# 6            Chinese  2905.0
# 7              Tamil  2600.0
# 8           Scottish  2485.0
# 9              Irish  2335.0
#
#
# ----Runnymede-Bloor West Village----
#                                 Origin   Count
# 0                              English  2515.0
# 1                                Irish  2450.0
# 2                             Scottish  2105.0
# 3                             Canadian  1855.0
# 4                               German  1180.0
# 5                            Ukrainian   935.0
# 6                               French   935.0
# 7                              Italian   935.0
# 8                               Polish   905.0
# 9        British Isles origins; n.i.e.   570.0
#
#
# ----Rustic----
#                                 Origin   Count
# 0                              Italian  2250.0
# 1                             Jamaican  1025.0
# 2                               Somali  1005.0
# 3                           Portuguese   800.0
# 4                             Canadian   715.0
# 5                             Filipino   405.0
# 6                              English   355.0
# 7        Other African origins; n.i.e.   340.0
# 8                              Spanish   320.0
# 9                          East Indian   315.0
#
#
# ----Scarborough Village----
#               Origin   Count
# 0        East Indian  2270.0
# 1           Canadian  1835.0
# 2            English  1360.0
# 3           Jamaican  1255.0
# 4         Sri Lankan  1190.0
# 5           Scottish  1140.0
# 6           Filipino  1040.0
# 7              Irish  1025.0
# 8        Bangladeshi   670.0
# 9            Chinese   665.0
#
#
# ----South Parkdale----
#            Origin   Count
# 0         English  3160.0
# 1           Irish  2970.0
# 2        Canadian  2705.0
# 3        Scottish  2615.0
# 4         Tibetan  1920.0
# 5        Filipino  1615.0
# 6          French  1545.0
# 7          German  1440.0
# 8          Polish  1195.0
# 9         Chinese  1050.0
#
#
# ----South Riverdale----
#                                 Origin   Count
# 0                              Chinese  6405.0
# 1                              English  5710.0
# 2                                Irish  5270.0
# 3                             Scottish  5105.0
# 4                             Canadian  5100.0
# 5                               French  2505.0
# 6                               German  2080.0
# 7                              Italian  1230.0
# 8        British Isles origins; n.i.e.  1160.0
# 9                               Polish  1115.0
#
#
# ----St.Andrew-Windfields----
#               Origin   Count
# 0            Chinese  3890.0
# 1            English  1940.0
# 2           Canadian  1705.0
# 3            Iranian  1365.0
# 4             Polish  1355.0
# 5              Irish  1255.0
# 6           Scottish  1240.0
# 7            Russian  1050.0
# 8        East Indian   870.0
# 9             Korean   830.0
#
#
# ----Steeles----
#               Origin    Count
# 0            Chinese  17835.0
# 1        East Indian   1115.0
# 2           Canadian    855.0
# 3           Filipino    675.0
# 4            English    560.0
# 5              Greek    430.0
# 6            Italian    365.0
# 7           Scottish    335.0
# 8         Sri Lankan    305.0
# 9           Egyptian    300.0
#
#
# ----Stonegate-Queensway----
#              Origin   Count
# 0           English  4555.0
# 1          Canadian  4060.0
# 2             Irish  4020.0
# 3          Scottish  3770.0
# 4            Polish  2900.0
# 5           Italian  2610.0
# 6         Ukrainian  2605.0
# 7            German  1870.0
# 8            French  1605.0
# 9        Portuguese  1235.0
#
#
# ----Tam O'Shanter-Sullivan----
#               Origin   Count
# 0            Chinese  9070.0
# 1        East Indian  2645.0
# 2           Filipino  2180.0
# 3           Canadian  2120.0
# 4            English  1850.0
# 5              Irish  1385.0
# 6           Scottish  1330.0
# 7         Sri Lankan  1015.0
# 8              Greek   945.0
# 9           Jamaican   935.0
#
#
# ----Taylor-Massey----
#               Origin   Count
# 0        Bangladeshi  1995.0
# 1        East Indian  1950.0
# 2           Canadian  1875.0
# 3            English  1560.0
# 4           Scottish  1195.0
# 5              Irish  1050.0
# 6            Chinese   835.0
# 7           Filipino   745.0
# 8            Bengali   710.0
# 9             German   600.0
#
#
# ----The Beaches----
#                                 Origin   Count
# 0                              English  7960.0
# 1                                Irish  6375.0
# 2                             Scottish  6065.0
# 3                             Canadian  5065.0
# 4                               French  2525.0
# 5                               German  2490.0
# 6                              Italian  1480.0
# 7                               Polish  1185.0
# 8        British Isles origins; n.i.e.  1155.0
# 9                                Dutch   970.0
#
#
# ----Thistletown-Beaumond Heights----
#               Origin   Count
# 0        East Indian  2030.0
# 1            Italian  1165.0
# 2           Canadian   835.0
# 3           Jamaican   615.0
# 4            English   525.0
# 5              Irish   440.0
# 6              Iraqi   415.0
# 7           Scottish   415.0
# 8           Ghanaian   330.0
# 9           Filipino   315.0
#
#
# ----Thorncliffe Park----
#                               Origin   Count
# 0                          Pakistani  4640.0
# 1                        East Indian  3725.0
# 2                             Afghan  1860.0
# 3                           Filipino  1565.0
# 4                           Canadian  1260.0
# 5                            English  1045.0
# 6        South Asian origins; n.i.e.   860.0
# 7                              Irish   845.0
# 8                           Scottish   725.0
# 9                            Chinese   625.0
#
#
# ----Trinity-Bellwoods----
#              Origin   Count
# 0           Chinese  3310.0
# 1        Portuguese  2925.0
# 2           English  2905.0
# 3             Irish  2520.0
# 4          Scottish  2410.0
# 5          Canadian  2350.0
# 6           Italian  1370.0
# 7            French  1230.0
# 8            German  1170.0
# 9            Polish   735.0
#
#
# ----University----
#              Origin   Count
# 0           English  1270.0
# 1             Irish  1220.0
# 2          Scottish   970.0
# 3          Canadian   970.0
# 4           Chinese   920.0
# 5            German   600.0
# 6            French   600.0
# 7            Polish   545.0
# 8        Portuguese   470.0
# 9           Italian   465.0
#
#
# ----Victoria Village----
#               Origin   Count
# 0           Canadian  1810.0
# 1        East Indian  1810.0
# 2            English  1700.0
# 3              Irish  1380.0
# 4           Scottish  1370.0
# 5           Filipino  1290.0
# 6              Greek  1230.0
# 7            Chinese   980.0
# 8           Jamaican   680.0
# 9             French   670.0
#
#
# ----Waterfront Communities-The Island----
#               Origin    Count
# 0            English  10640.0
# 1            Chinese   9790.0
# 2              Irish   9530.0
# 3           Canadian   8870.0
# 4           Scottish   8355.0
# 5        East Indian   5550.0
# 6             French   5200.0
# 7             German   4805.0
# 8            Italian   4350.0
# 9             Polish   2755.0
#
#
# ----West Hill----
#               Origin   Count
# 0           Canadian  3890.0
# 1            English  3120.0
# 2        East Indian  2660.0
# 3           Jamaican  2595.0
# 4           Filipino  2545.0
# 5              Irish  2425.0
# 6           Scottish  2210.0
# 7            Chinese  1215.0
# 8            Italian  1115.0
# 9             German  1050.0
#
#
# ----West Humber-Clairville----
#               Origin    Count
# 0        East Indian  11565.0
# 1           Jamaican   2460.0
# 2           Canadian   2395.0
# 3           Filipino   1755.0
# 4            Italian   1685.0
# 5            Punjabi   1450.0
# 6            English   1315.0
# 7           Guyanese   1210.0
# 8            Chinese    880.0
# 9           Scottish    825.0
#
#
# ----Westminster-Branson----
#             Origin   Count
# 0         Filipino  6045.0
# 1          Russian  4950.0
# 2           Jewish  2640.0
# 3        Ukrainian  2000.0
# 4           Polish  1840.0
# 5         Canadian  1560.0
# 6          Chinese  1045.0
# 7          English   970.0
# 8           Korean   925.0
# 9         Romanian   740.0
#
#
# ----Weston----
#                                 Origin   Count
# 0                             Jamaican  2360.0
# 1                             Canadian  1820.0
# 2                              Italian  1575.0
# 3                              English  1500.0
# 4                             Scottish  1330.0
# 5                           Portuguese  1250.0
# 6                                Irish  1225.0
# 7                               Somali  1085.0
# 8        Other African origins; n.i.e.   880.0
# 9                              Spanish   695.0
#
#
# ----Weston-Pelham Park----
#              Origin   Count
# 0        Portuguese  3380.0
# 1          Canadian  1190.0
# 2           Italian  1125.0
# 3           English  1080.0
# 4             Irish   815.0
# 5          Scottish   775.0
# 6        Vietnamese   565.0
# 7           Chinese   430.0
# 8            French   415.0
# 9          Jamaican   380.0
#
#
# ----Wexford/Maryvale----
#               Origin   Count
# 0           Canadian  3710.0
# 1           Filipino  3535.0
# 2            English  2695.0
# 3              Greek  2325.0
# 4            Chinese  2310.0
# 5              Irish  2010.0
# 6        East Indian  1935.0
# 7           Scottish  1915.0
# 8            Italian  1285.0
# 9         Sri Lankan  1065.0
#
#
# ----Willowdale East----
#               Origin    Count
# 0            Chinese  17240.0
# 1            Iranian   6805.0
# 2             Korean   5395.0
# 3        East Indian   2640.0
# 4            English   2575.0
# 5           Canadian   2325.0
# 6           Scottish   1900.0
# 7              Irish   1850.0
# 8            Russian   1630.0
# 9            Italian   1475.0
#
#
# ----Willowdale West----
#               Origin   Count
# 0            Chinese  3825.0
# 1             Korean  1955.0
# 2            Iranian  1890.0
# 3            English  1505.0
# 4           Canadian  1245.0
# 5              Irish  1065.0
# 6           Scottish   975.0
# 7            Russian   955.0
# 8            Italian   825.0
# 9        East Indian   695.0
#
#
# ----Willowridge-Martingrove-Richview----
#               Origin   Count
# 0            Italian  4280.0
# 1            English  2440.0
# 2           Canadian  2085.0
# 3           Scottish  1720.0
# 4              Irish  1695.0
# 5        East Indian  1385.0
# 6         Portuguese  1060.0
# 7          Ukrainian  1050.0
# 8             Polish  1025.0
# 9             German   890.0
#
#
# ----Woburn----
#               Origin    Count
# 0        East Indian  12465.0
# 1           Canadian   5265.0
# 2         Sri Lankan   4725.0
# 3            Chinese   4385.0
# 4           Filipino   4345.0
# 5            English   3960.0
# 6              Irish   2780.0
# 7           Scottish   2760.0
# 8           Jamaican   2740.0
# 9              Tamil   1750.0
#
#
# ----Woodbine Corridor----
#               Origin   Count
# 0            English  3730.0
# 1           Canadian  3170.0
# 2              Irish  3035.0
# 3           Scottish  2915.0
# 4             German  1430.0
# 5             French  1380.0
# 6            Chinese  1260.0
# 7            Italian   690.0
# 8             Polish   595.0
# 9        East Indian   530.0
#
#
# ----Woodbine-Lumsden----
#            Origin   Count
# 0         English  1670.0
# 1           Irish  1580.0
# 2        Canadian  1525.0
# 3        Scottish  1485.0
# 4         Chinese   805.0
# 5          French   705.0
# 6          German   660.0
# 7         Italian   575.0
# 8           Greek   410.0
# 9          Polish   390.0
#
#
# ----Wychwood----
#              Origin   Count
# 0           English  2455.0
# 1             Irish  2050.0
# 2          Scottish  1915.0
# 3          Canadian  1800.0
# 4           Italian  1415.0
# 5            French  1165.0
# 6            German  1110.0
# 7        Portuguese  1090.0
# 8            Polish  1070.0
# 9           Chinese  1000.0
#
#
# ----Yonge-Eglinton----
#            Origin   Count
# 0         English  2845.0
# 1        Canadian  2450.0
# 2           Irish  2400.0
# 3        Scottish  2395.0
# 4          German  1145.0
# 5         Chinese  1100.0
# 6          French  1080.0
# 7          Polish   905.0
# 8         Italian   755.0
# 9         Russian   625.0
#
#
# ----Yonge-St.Clair----
#            Origin   Count
# 0         English  3190.0
# 1        Scottish  2665.0
# 2           Irish  2595.0
# 3        Canadian  2270.0
# 4          German  1230.0
# 5          Polish  1115.0
# 6          French  1005.0
# 7         Russian   835.0
# 8         Italian   825.0
# 9         Chinese   645.0
#
#
# ----York University Heights----
#               Origin   Count
# 0            Italian  3465.0
# 1           Filipino  2715.0
# 2        East Indian  2315.0
# 3            Chinese  2105.0
# 4           Jamaican  2045.0
# 5           Canadian  1890.0
# 6         Vietnamese  1290.0
# 7            English  1170.0
# 8         Sri Lankan   915.0
# 9              Irish   880.0
#
#
# ----Yorkdale-Glen Park----
#               Origin   Count
# 0            Italian  4055.0
# 1         Portuguese  1455.0
# 2           Filipino  1190.0
# 3            Chinese  1130.0
# 4           Canadian   955.0
# 5        East Indian   780.0
# 6         Vietnamese   605.0
# 7            English   585.0
# 8           Jamaican   570.0
# 9              Irish   425.0

# %% [markdown]
# #### 4/ Put the results into a Pandas dataframe

# %% [markdown]
# Function to sort the venues in descending order.

# %%
def return_most_common_ethn(row, num_top):
    # Remove the key from the row
    row_categories = row.iloc[1:].astype(float)
    
    # Sort ascending
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    # Return the top num_top_venues
    return row_categories_sorted.index.values[0:num_top]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City_Area']

for ind in np.arange(num_top):
    try:
        columns.append('{}{} Most Common Origin'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Origin'.format(ind+1))

# create a new dataframe, and set it with the columns names
areas_ethn_sorted = pd.DataFrame(columns=columns)

# add the keys from the grouped dataframe (City_Area)
areas_ethn_sorted['City_Area'] = df_demographic['City_Area']

# loop through each rows
for ind in np.arange(df_demographic.shape[0]):
    areas_ethn_sorted.iloc[ind, 1:] = return_most_common_ethn(df_demographic.iloc[ind, :], num_top)

areas_ethn_sorted.head()
# Out:
#                       City_Area 1st Most Common Origin 2nd Most Common Origin  \
# 0               Agincourt North                Chinese             Sri Lankan
# 1  Agincourt South-Malvern West                Chinese            East Indian
# 2                     Alderwood                English               Canadian
# 3                         Annex                English                  Irish
# 4             Banbury-Don Mills                Chinese                English
#
#   3rd Most Common Origin 4th Most Common Origin 5th Most Common Origin  \
# 0            East Indian               Filipino               Canadian
# 1               Filipino             Sri Lankan               Canadian
# 2                  Irish               Scottish                Italian
# 3               Scottish               Canadian                 German
# 4                  Irish               Canadian               Scottish
#
#   6th Most Common Origin 7th Most Common Origin 8th Most Common Origin  \
# 0                English                  Tamil               Jamaican
# 1                English               Scottish               Jamaican
# 2                 Polish                 German                 French
# 3                 French                 Polish                Chinese
# 4            East Indian                 German               Filipino
#
#   9th Most Common Origin 10th Most Common Origin
# 0               Scottish                   Irish
# 1                Italian                   Irish
# 2              Ukrainian              Portuguese
# 3                Italian                 Russian
# 4                 Polish                  French

# %% [markdown]
# #### 5/ Cluster areas

# %%
# set number of clusters
kclusters = 5

toronto_areas_clustering = df_demographic.drop('City_Area', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_areas_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 3, 0, 4, 1, 0, 1, 1, 1, 0], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
areas_ethn_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_merged = df_cityAreas

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(areas_ethn_sorted.set_index(['City_Area']), on=['City_Area'])

toronto_merged.head() # check the last columns!
# Out:
#    CDN                     City_Area  Latitude  Longitude  Cluster Labels  \
# 0  129               Agincourt North  43.80930  -79.26707               3
# 1  128  Agincourt South-Malvern West  43.78735  -79.26941               3
# 2   20                     Alderwood  43.60496  -79.54116               0
# 3   95                         Annex  43.66936  -79.40280               4
# 4   42             Banbury-Don Mills  43.74041  -79.34852               1
#
#   1st Most Common Origin 2nd Most Common Origin 3rd Most Common Origin  \
# 0                Chinese             Sri Lankan            East Indian
# 1                Chinese            East Indian               Filipino
# 2                English               Canadian                  Irish
# 3                English                  Irish               Scottish
# 4                Chinese                English                  Irish
#
#   4th Most Common Origin 5th Most Common Origin 6th Most Common Origin  \
# 0               Filipino               Canadian                English
# 1             Sri Lankan               Canadian                English
# 2               Scottish                Italian                 Polish
# 3               Canadian                 German                 French
# 4               Canadian               Scottish            East Indian
#
#   7th Most Common Origin 8th Most Common Origin 9th Most Common Origin  \
# 0                  Tamil               Jamaican               Scottish
# 1               Scottish               Jamaican                Italian
# 2                 German                 French              Ukrainian
# 3                 Polish                Chinese                Italian
# 4                 German               Filipino                 Polish
#
#   10th Most Common Origin
# 0                   Irish
# 1                   Irish
# 2              Portuguese
# 3                 Russian
# 4                  French

# %% [markdown]
# Visualise the clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cityArea, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['City_Area'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(cityArea) + ' - Cluster ' + str(cluster), parse_html=True)
    cluster = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 6/ Examine clusters

# %% [markdown]
# **Cluster 0** regroups areas higly habited by **European and Canadian people**.
# We can see **English, Italian, Portuguese, French people** ...
# These clusters are represented by red circles on the map. We can see that most of them are positioned in almost all the south of Toronto, and in the downtown.

# %%
toronto_merged[toronto_merged['Cluster Labels'] == 0].head(50)
# Out:
#     CDN                          City_Area   Latitude  Longitude  \
# 2    20                          Alderwood  43.604960 -79.541160
# 5    34                     Bathurst Manor  43.763780 -79.454770
# 9    39               Bedford Park-Nortown  43.730660 -79.424500
# 10  112            Beechborough-Greenbrook  43.693110 -79.478310
# 13   24                        Black Creek  43.766360 -79.521500
# 14   69                        Blake-Jones  43.675220 -79.337620
# 15  108               Briar Hill-Belgravia  43.698520 -79.451250
# 16   41  Bridle Path-Sunnybrook-York Mills  43.727320 -79.380810
# 17   57                    Broadview North  43.689370 -79.354290
# 18   30                Brookhaven-Amesbury  43.700310 -79.484650
# 19   71   Cabbagetown-South St. James Town  43.667600 -79.364190
# 20  109                 Caledonia-Fairbank  43.688570 -79.454830
# 21   96                          Casa Loma  43.680780 -79.409490
# 22  133             Centennial Scarborough  43.779120 -79.147240
# 24  120                Clairlea-Birchmount  43.715990 -79.283700
# 25   33                       Clanton Park  43.743590 -79.443210
# 26  123                         Cliffcrest  43.726420 -79.232970
# 27   92             Corso Italia-Davenport  43.676990 -79.450380
# 28   66                           Danforth  43.677020 -79.354620
# 29   59                 Danforth East York  43.690655 -79.290818
# 33   26               Downsview-Roding-CFB  43.728920 -79.491360
# 34   83                     Dufferin Grove  43.655140 -79.437310
# 36    9           Edenbridge-Humber Valley  43.669910 -79.521260
# 37  138                      Eglinton East  43.739680 -79.245540
# 38    5                   Elms-Old Rexdale  43.724290 -79.549560
# 39   32                Englemount-Lawrence  43.721920 -79.438120
# 40   11     Eringate-Centennial-West Deane  43.661910 -79.577380
# 41   13                Etobicoke West Mall  43.644450 -79.567720
# 42   44                    Flemingdon Park  43.716310 -79.331710
# 43  102                  Forest Hill North  43.705220 -79.427450
# 44  101                  Forest Hill South  43.694310 -79.416100
# 45   25             Glenfield-Jane Heights  43.746750 -79.515040
# 46   65                  Greenwood-Coxwell  43.671950 -79.323430
# 47  140                          Guildwood  43.749530 -79.189920
# 51  134                     Highland Creek  43.789480 -79.176140
# 53    8           Humber Heights-Westmount  43.694020 -79.521260
# 54   21                      Humber Summit  43.760160 -79.558490
# 55   22                         Humbermede  43.742840 -79.537460
# 56  106                 Humewood-Cedarvale  43.689420 -79.426980
# 57  125                            Ionview  43.736290 -79.273200
# 59   90                      Junction Area  43.669070 -79.472030
# 60  110           Keelesdale-Eglinton West  43.685690 -79.469280
# 61  124                       Kennedy Park  43.725870 -79.262320
# 63    6      Kingsview Village-The Westway  43.699440 -79.549240
# 64   15                     Kingsway South  43.654330 -79.511120
# 65  114                 Lambton Baby Point  43.659320 -79.497510
# 67   38                   Lansing-Westgate  43.754630 -79.424200
# 71   84                    Little Portugal  43.647480 -79.429030
# 72   19                        Long Branch  43.593530 -79.532720
# 74   29                         Maple Leaf  43.714620 -79.479780
#
#     Cluster Labels 1st Most Common Origin 2nd Most Common Origin  \
# 2                0                English               Canadian
# 5                0               Filipino                Russian
# 9                0               Canadian                 Polish
# 10               0             Portuguese               Jamaican
# 13               0             Vietnamese               Jamaican
# 14               0                English               Canadian
# 15               0               Filipino                Italian
# 16               0                English               Scottish
# 17               0                English                  Irish
# 18               0                Italian             Portuguese
# 19               0                English                  Irish
# 20               0             Portuguese                Italian
# 21               0                English                  Irish
# 22               0                English               Canadian
# 24               0               Canadian               Filipino
# 25               0               Filipino                 Polish
# 26               0                English               Canadian
# 27               0             Portuguese                Italian
# 28               0                English               Canadian
# 29               0                English                  Irish
# 33               0                Italian               Filipino
# 34               0             Portuguese                English
# 36               0                Italian                English
# 37               0               Filipino            East Indian
# 38               0               Canadian                 Somali
# 39               0               Filipino                 Polish
# 40               0               Canadian                English
# 41               0                English               Canadian
# 42               0            East Indian               Filipino
# 43               0                 Polish                Russian
# 44               0                 Polish               Canadian
# 45               0                Italian             Vietnamese
# 46               0                English               Canadian
# 47               0                English                  Irish
# 51               0            East Indian             Sri Lankan
# 53               0                Italian              Ukrainian
# 54               0                Italian            East Indian
# 55               0            East Indian                Italian
# 56               0               Canadian                English
# 57               0               Filipino            East Indian
# 59               0                English                  Irish
# 60               0             Portuguese                Italian
# 61               0               Filipino               Canadian
# 63               0                 Somali                Italian
# 64               0                English                  Irish
# 65               0                English               Scottish
# 67               0               Canadian                Chinese
# 71               0             Portuguese                English
# 72               0               Canadian                English
# 74               0                Italian               Filipino
#
#    3rd Most Common Origin 4th Most Common Origin 5th Most Common Origin  \
# 2                   Irish               Scottish                Italian
# 5                 Italian                 Polish               Canadian
# 9                 English                Russian               Scottish
# 10                Italian               Canadian               Filipino
# 13               Canadian                Italian            East Indian
# 14                  Irish               Scottish                Chinese
# 15             Portuguese               Canadian                English
# 16               Canadian                Chinese                  Irish
# 17               Scottish                  Greek               Canadian
# 18               Jamaican               Canadian               Filipino
# 19               Scottish               Canadian                 German
# 20               Canadian               Filipino                English
# 21               Scottish               Canadian                 Polish
# 22               Scottish                  Irish            East Indian
# 24                English                Chinese            East Indian
# 25               Canadian                Italian                Russian
# 26               Scottish                  Irish            East Indian
# 27               Canadian                English                  Irish
# 28                  Irish               Scottish                Italian
# 29               Canadian               Scottish                  Greek
# 33               Canadian               Jamaican             Vietnamese
# 34               Scottish               Canadian                  Irish
# 36                  Irish               Canadian               Scottish
# 37               Canadian             Sri Lankan               Jamaican
# 38                Italian               Jamaican                English
# 39               Canadian                Russian                 Jewish
# 40                Italian                  Irish               Scottish
# 41               Scottish                  Irish              Ukrainian
# 42                 Afghan              Pakistani                Chinese
# 43               Canadian               Filipino                English
# 44                Russian                English               Scottish
# 45               Jamaican                Chinese            East Indian
# 46                  Irish               Scottish                Chinese
# 47               Scottish               Canadian                 German
# 51                Chinese               Canadian               Filipino
# 53               Canadian                English                  Irish
# 54              Pakistani               Jamaican               Canadian
# 55               Canadian               Jamaican             Vietnamese
# 56                 Polish               Scottish                  Irish
# 57               Canadian                English                Chinese
# 59               Scottish               Canadian                 German
# 60               Filipino            East Indian               Canadian
# 61            East Indian                English                Chinese
# 63            East Indian               Canadian                English
# 64               Canadian               Scottish                Italian
# 65                  Irish               Canadian                 German
# 67                English                 Polish                Russian
# 71               Canadian                  Irish               Scottish
# 72                  Irish               Scottish                 Polish
# 74             Portuguese            East Indian               Canadian
#
#    6th Most Common Origin 7th Most Common Origin  \
# 2                  Polish                 German
# 5                  Jewish                Chinese
# 9                   Irish               Filipino
# 10            East Indian                English
# 13                Chinese               Filipino
# 14                 French                 German
# 15               Scottish                  Irish
# 16                Italian                 German
# 17                 French                 German
# 18             Vietnamese                Chinese
# 19                 French                Chinese
# 20                  Irish                Spanish
# 21                Russian                 German
# 22                Chinese                Italian
# 24                  Irish               Scottish
# 25                 Jewish                English
# 26                Chinese                 German
# 27               Scottish                 French
# 28                Chinese                 German
# 29                Chinese                 German
# 33             Portuguese                Chinese
# 34                Chinese                 French
# 36              Ukrainian                 Polish
# 37                English                Chinese
# 38               Filipino            East Indian
# 39              Hungarian                English
# 40              Ukrainian                 Polish
# 41                 Polish                Italian
# 42               Canadian                  Greek
# 43                 Jewish               Scottish
# 44                  Irish                 Jewish
# 45               Canadian               Filipino
# 46                 French                 German
# 47                 French            East Indian
# 51                English               Jamaican
# 53             Portuguese               Scottish
# 54             Vietnamese                  Iraqi
# 55               Filipino              Pakistani
# 56               Filipino                Russian
# 57             Sri Lankan                  Irish
# 59                 French             Portuguese
# 60               Jamaican                English
# 61                  Irish               Scottish
# 63               Jamaican               Scottish
# 64                 German                 French
# 65                 Polish              Ukrainian
# 67                  Irish               Scottish
# 71                Chinese                 French
# 72                 German              Ukrainian
# 74                English               Jamaican
#
#                  8th Most Common Origin               9th Most Common Origin  \
# 2                                French                            Ukrainian
# 5                               English                            Ukrainian
# 9                                Jewish                               German
# 10                              Spanish                           Vietnamese
# 13                                Iraqi                             Ghanaian
# 14                                Greek                          East Indian
# 15                             Albanian                              Russian
# 16                               French                              Russian
# 17                              Chinese                             Filipino
# 18        Other African origins; n.i.e.                              English
# 19                              Italian        British Isles origins; n.i.e.
# 20                             Scottish                              Chinese
# 21                               French                              Italian
# 22                               German                             Filipino
# 24                          Bangladeshi                              Italian
# 25                              Chinese                               German
# 26                               French                              Italian
# 27                               German                              Spanish
# 28                               French                                Greek
# 29                              Italian                               French
# 33                              English                              Spanish
# 34                               German                              Italian
# 36                               German                               French
# 37                             Scottish                                Irish
# 38                             Scottish                                Irish
# 39                              Italian                               German
# 40                               German                              Chinese
# 41                             Filipino                          East Indian
# 42                              English                           Sri Lankan
# 43                                Irish                             Romanian
# 44                               German                               French
# 45                              Spanish                             Guyanese
# 46                              Italian                               Polish
# 47                              Italian                             Filipino
# 51                                Irish                              Italian
# 53                               Polish                               German
# 54                             Filipino                              English
# 55                              Spanish                              Chinese
# 56                               German                              Italian
# 57                             Scottish                             Jamaican
# 59                              Chinese                              Italian
# 60                              Spanish                                Irish
# 61                           Sri Lankan                          Bangladeshi
# 63                                Irish                            Pakistani
# 64                               Polish                            Ukrainian
# 65                              Italian                               French
# 67                             Filipino                              Iranian
# 71                              Italian                               German
# 72                               French                              Italian
# 74                           Vietnamese                              Chinese
#
#                 10th Most Common Origin
# 2                            Portuguese
# 5                                 Greek
# 9                               Italian
# 10        Other African origins; n.i.e.
# 13        Other African origins; n.i.e.
# 14                             Jamaican
# 15                               Polish
# 16                               Polish
# 17                              Serbian
# 18                          East Indian
# 19                               Polish
# 20                               French
# 21                               Jewish
# 22                               French
# 24                                Greek
# 25                            Hungarian
# 26                             Filipino
# 27                              Chinese
# 28                          East Indian
# 29                          East Indian
# 33                          East Indian
# 34                               Polish
# 36                           Portuguese
# 37                                Tamil
# 38        Other African origins; n.i.e.
# 39                             American
# 40                           Portuguese
# 41                              Serbian
# 42                               Slovak
# 43                               German
# 44                              Chinese
# 45                              English
# 46                          East Indian
# 47                              Chinese
# 51                             Scottish
# 53                              Spanish
# 54                              Spanish
# 55                              English
# 56                               Jewish
# 57                                Greek
# 59                               Polish
# 60                             Scottish
# 61                             Jamaican
# 63                           Portuguese
# 64        British Isles origins; n.i.e.
# 65                           Portuguese
# 67                          East Indian
# 71                               Polish
# 72                             Filipino
# 74                                Irish

# %% [markdown]
# **Cluster 1** regroups areas higly habited by **Chinese people, and people from others countries in Asia**.
# These are represented by violet circles on the map. We can see that most of them are positioned at the north of Toronto.

# %%
toronto_merged[toronto_merged['Cluster Labels'] == 1].head(50)
# Out:
#      CDN               City_Area  Latitude  Longitude  Cluster Labels  \
# 4     42       Banbury-Don Mills  43.74041  -79.34852               1
# 6     76     Bay Street Corridor  43.65771  -79.38618               1
# 7     52         Bayview Village  43.77710  -79.37957               1
# 8     49   Bayview Woods-Steeles  43.79485  -79.38220               1
# 11   127                 Bendale  43.75963  -79.25739               1
# 30    47      Don Valley Village  43.78552  -79.35017               1
# 31   126             Dorset Park  43.75533  -79.27746               1
# 48    53              Henry Farm  43.77230  -79.34087               1
# 52    48       Hillcrest Village  43.80303  -79.35346               1
# 62    78    Kensington-Chinatown  43.65331  -79.39634               1
# 85    50        Newtonbrook East  43.79304  -79.40695               1
# 86    36        Newtonbrook West  43.78818  -79.43173               1
# 98    46           Pleasant View  43.78812  -79.33453               1
# 111   40    St.Andrew-Windfields  43.75720  -79.38188               1
# 114  118  Tam O'Shanter-Sullivan  43.78203  -79.30540               1
# 130   37         Willowdale West  43.77094  -79.42785               1
#
#     1st Most Common Origin 2nd Most Common Origin 3rd Most Common Origin  \
# 4                  Chinese                English                  Irish
# 6                  Chinese                English               Canadian
# 7                  Chinese                Iranian                 Korean
# 8                  Chinese                Iranian                English
# 11                 Chinese            East Indian               Filipino
# 30                 Chinese               Filipino            East Indian
# 31                Filipino            East Indian                Chinese
# 48                 Chinese            East Indian               Filipino
# 52                 Chinese            East Indian               Canadian
# 62                 Chinese               Canadian                English
# 85                 Chinese                Iranian                 Korean
# 86                Filipino                Chinese                Russian
# 98                 Chinese                  Greek                Italian
# 111                Chinese                English               Canadian
# 114                Chinese            East Indian               Filipino
# 130                Chinese                 Korean                Iranian
#
#     4th Most Common Origin 5th Most Common Origin 6th Most Common Origin  \
# 4                 Canadian               Scottish            East Indian
# 6                 Scottish                  Irish            East Indian
# 7                  English               Canadian                  Irish
# 8                 Canadian                 Korean                 Polish
# 11                Canadian                English               Scottish
# 30                 Iranian                English               Canadian
# 31                Canadian             Sri Lankan                English
# 48                 Iranian               Canadian                English
# 52                 Iranian                 Korean                English
# 62                   Irish               Scottish                 French
# 85                 English               Canadian                  Irish
# 86                  Korean                Iranian                 Jewish
# 98                Canadian            East Indian                English
# 111                Iranian                 Polish                  Irish
# 114               Canadian                English                  Irish
# 130                English               Canadian                  Irish
#
#     7th Most Common Origin 8th Most Common Origin 9th Most Common Origin  \
# 4                   German               Filipino                 Polish
# 6                   Korean                 German                 French
# 7                 Scottish            East Indian               Filipino
# 8                    Irish               Scottish                Russian
# 11                   Irish             Sri Lankan                  Greek
# 30                   Irish               Scottish                 Korean
# 31                Jamaican               Scottish                  Tamil
# 48                Scottish                  Irish                 Afghan
# 52                 Russian               Scottish                 Polish
# 62                  German                Italian                 Polish
# 85                Scottish                Italian            East Indian
# 86                 Italian              Ukrainian                English
# 98                Scottish               Filipino                  Irish
# 111               Scottish                Russian            East Indian
# 114               Scottish             Sri Lankan                  Greek
# 130               Scottish                Russian                Italian
#
#     10th Most Common Origin
# 4                    French
# 6                   Italian
# 7                    Polish
# 8               East Indian
# 11                   French
# 30                 Armenian
# 31                    Irish
# 48                   Korean
# 52                    Irish
# 62              East Indian
# 85                 Filipino
# 86                 Canadian
# 98                  Iranian
# 111                  Korean
# 114                Jamaican
# 130             East Indian

# %% [markdown]
# **Cluster 2** concentrates areas haghly habited by **Indian people**.
# These clusters are represented by dark green. We can see that these areas are located at the edges of Toronto.

# %%
toronto_merged[toronto_merged['Cluster Labels'] == 2].head(10)
# Out:
#      CDN                          City_Area  Latitude  Longitude  \
# 73   132                            Malvern  43.80977  -79.22084
# 81     2  Mount Olive-Silverstone-Jamestown  43.74721  -79.58826
# 105  131                              Rouge  43.80766  -79.17405
# 124    1             West Humber-Clairville  43.71451  -79.59292
# 132  137                             Woburn  43.76730  -79.22823
#
#      Cluster Labels 1st Most Common Origin 2nd Most Common Origin  \
# 73                2            East Indian             Sri Lankan
# 81                2            East Indian                  Iraqi
# 105               2            East Indian             Sri Lankan
# 124               2            East Indian               Jamaican
# 132               2            East Indian               Canadian
#
#     3rd Most Common Origin 4th Most Common Origin 5th Most Common Origin  \
# 73                Filipino                Chinese               Jamaican
# 81                Jamaican               Canadian                 Somali
# 105               Canadian               Filipino               Jamaican
# 124               Canadian               Filipino                Italian
# 132             Sri Lankan                Chinese               Filipino
#
#     6th Most Common Origin 7th Most Common Origin 8th Most Common Origin  \
# 73                Canadian                English                  Tamil
# 81                 Italian               Assyrian             Sri Lankan
# 105                English                Chinese                  Tamil
# 124                Punjabi                English               Guyanese
# 132                English                  Irish               Scottish
#
#                   9th Most Common Origin 10th Most Common Origin
# 73                              Guyanese               Pakistani
# 81         Other African origins; n.i.e.                Ghanaian
# 105                             Scottish                   Irish
# 124                              Chinese                Scottish
# 132                             Jamaican                   Tamil

# %% [markdown]
# **Cluster 3** also regroups areas higly habited by **asian people, the most common ethnic origin is Chinese**.
# These are represented by light green circles on the map. We can see that most of them are positioned at the north east of Toronto, next to the cluster 1.

# %%
toronto_merged[toronto_merged['Cluster Labels'] == 3].head(10)
# Out:
#      CDN                     City_Area  Latitude  Longitude  Cluster Labels  \
# 0    129               Agincourt North  43.80930  -79.26707               3
# 1    128  Agincourt South-Malvern West  43.78735  -79.26941               3
# 66   117                    L'Amoreaux  43.79726  -79.31220               3
# 76   130                      Milliken  43.82280  -79.27694               3
# 112  116                       Steeles  43.81219  -79.32128               3
# 129   51               Willowdale East  43.77248  -79.40039               3
#
#     1st Most Common Origin 2nd Most Common Origin 3rd Most Common Origin  \
# 0                  Chinese             Sri Lankan            East Indian
# 1                  Chinese            East Indian               Filipino
# 66                 Chinese            East Indian               Canadian
# 76                 Chinese             Sri Lankan            East Indian
# 112                Chinese            East Indian               Canadian
# 129                Chinese                Iranian                 Korean
#
#     4th Most Common Origin 5th Most Common Origin 6th Most Common Origin  \
# 0                 Filipino               Canadian                English
# 1               Sri Lankan               Canadian                English
# 66              Sri Lankan               Filipino                English
# 76                Filipino               Canadian                  Tamil
# 112               Filipino                English                  Greek
# 129            East Indian                English               Canadian
#
#     7th Most Common Origin 8th Most Common Origin 9th Most Common Origin  \
# 0                    Tamil               Jamaican               Scottish
# 1                 Scottish               Jamaican                Italian
# 66                Armenian               Jamaican               Scottish
# 76                Jamaican                English             Vietnamese
# 112                Italian               Scottish             Sri Lankan
# 129               Scottish                  Irish                Russian
#
#     10th Most Common Origin
# 0                     Irish
# 1                     Irish
# 66                    Irish
# 76                  Spanish
# 112                Egyptian
# 129                 Italian

# %% [markdown]
# **Cluster 4** regroups areas higly habited by **English, Irish, Scottish and Canadian** people.
# We can also see that there are a lot of people from other **european countries as well, such as French, German, Polish**, ...
# These are represented by yellow circles on the map. We can see that most of them are positioned at the south and in the downtown of Toronto.

# %%
toronto_merged[toronto_merged['Cluster Labels'] == 4].head(50)
# Out:
#      CDN                            City_Area  Latitude  Longitude  \
# 3     95                                Annex  43.66936  -79.40280
# 12   122                Birchcliffe-Cliffside  43.69472  -79.26460
# 23    75                Church-Yonge Corridor  43.66024  -79.37868
# 32    93  Dovercourt-Wallace Emerson-Junction  43.66604  -79.43687
# 35    62                    East End-Danforth  43.68415  -79.29911
# 49    88                      High Park North  43.65767  -79.46458
# 50    87                    High Park-Swansea  43.64704  -79.47114
# 58    14           Islington-City Centre West  43.63608  -79.54296
# 68   105                  Lawrence Park North  43.72830  -79.40642
# 69   103                  Lawrence Park South  43.71853  -79.40574
# 70    56                   Leaside-Bennington  43.70071  -79.36758
# 77    17  Mimico (includes Humber Bay Shores)  43.61729  -79.49885
# 82    99                  Mount Pleasant East  43.70563  -79.38193
# 83   104                  Mount Pleasant West  43.70541  -79.39256
# 87    82                              Niagara  43.64285  -79.40790
# 95    45                    Parkwoods-Donalda  43.75613  -79.32880
# 104   98                  Rosedale-Moore Park  43.68191  -79.37937
# 110   70                      South Riverdale  43.65221  -79.33820
# 113   16                  Stonegate-Queensway  43.63718  -79.50058
# 116   63                          The Beaches  43.67413  -79.29644
# 122   77    Waterfront Communities-The Island  43.64296  -79.37161
#
#      Cluster Labels 1st Most Common Origin 2nd Most Common Origin  \
# 3                 4                English                  Irish
# 12                4                English                  Irish
# 23                4                English                  Irish
# 32                4             Portuguese                English
# 35                4                English                  Irish
# 49                4                English                  Irish
# 50                4                English                  Irish
# 58                4                English               Canadian
# 68                4                English               Scottish
# 69                4                English               Scottish
# 70                4                English               Scottish
# 77                4                English               Canadian
# 82                4                English                  Irish
# 83                4                English               Scottish
# 87                4                English                  Irish
# 95                4               Canadian                English
# 104               4                English               Scottish
# 110               4                Chinese                English
# 113               4                English               Canadian
# 116               4                English                  Irish
# 122               4                English                Chinese
#
#     3rd Most Common Origin 4th Most Common Origin 5th Most Common Origin  \
# 3                 Scottish               Canadian                 German
# 12                Canadian               Scottish                 French
# 23                Scottish                Chinese               Canadian
# 32                Canadian                  Irish               Scottish
# 35                Scottish               Canadian                 French
# 49                Scottish               Canadian                 German
# 50                Scottish               Canadian                 German
# 58                 Italian                  Irish               Scottish
# 68                Canadian                  Irish                 German
# 69                Canadian                  Irish                 German
# 70                   Irish               Canadian                 German
# 77                   Irish               Scottish                Italian
# 82                Scottish               Canadian                 German
# 83                Canadian                  Irish                 German
# 87                Canadian               Scottish                 German
# 95                 Chinese               Scottish                  Irish
# 104                  Irish               Canadian                 German
# 110                  Irish               Scottish               Canadian
# 113                  Irish               Scottish                 Polish
# 116               Scottish               Canadian                 French
# 122                  Irish               Canadian               Scottish
#
#     6th Most Common Origin 7th Most Common Origin 8th Most Common Origin  \
# 3                   French                 Polish                Chinese
# 12                  German                Chinese                Italian
# 23                  French                 German            East Indian
# 32                 Chinese                Italian                 German
# 35                  German                Chinese                Italian
# 49                  Polish                 French              Ukrainian
# 50                  Polish                 French                Italian
# 58                  Polish              Ukrainian            East Indian
# 68                 Chinese                 French                 Polish
# 69                  Polish                Russian                 French
# 70                  French                Italian                Chinese
# 77                  Polish              Ukrainian                 German
# 82                  French                 Polish                Chinese
# 83                  French                 Polish                Russian
# 87                 Chinese                Italian                 French
# 95                Filipino            East Indian                 German
# 104                 French                Chinese                 Polish
# 110                 French                 German                Italian
# 113                Italian              Ukrainian                 German
# 116                 German                Italian                 Polish
# 122            East Indian                 French                 German
#
#                   9th Most Common Origin              10th Most Common Origin
# 3                                Italian                              Russian
# 12                              Filipino        British Isles origins; n.i.e.
# 23                               Italian                               Polish
# 32                                French                          East Indian
# 35                                Polish        British Isles origins; n.i.e.
# 49                               Italian                              Russian
# 50                             Ukrainian        British Isles origins; n.i.e.
# 58                                German                              Chinese
# 68                               Italian                              Russian
# 69                               Italian                              Chinese
# 70         British Isles origins; n.i.e.                               Polish
# 77                                French                              Chinese
# 82                               Italian                              Russian
# 83                           East Indian                              Chinese
# 87                           East Indian                               Polish
# 95                              Jamaican                               French
# 104                              Italian        British Isles origins; n.i.e.
# 110        British Isles origins; n.i.e.                               Polish
# 113                               French                           Portuguese
# 116        British Isles origins; n.i.e.                                Dutch
# 122                              Italian                               Polish

# %% [markdown]
# # Part 4 - Use cases

# %% [markdown]
# This function will retrieve the FoursquareAPI venues for all the neighbourhoods given in parameters

# %%
def getNearbyVenues(cdn, latitudes, longitudes):
    
    venues_list=[]
    # Loop through each neighbourhood given in parameters
    for cdn, lat, lng in zip(cdn, latitudes, longitudes):

        # create the API request URL to explore the neighbourhood using FoursquareAPI
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            CONST_venuesRadiusScan, 
            CONST_venuesLimit)

        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue : name, latitude, longitude, and the categories' names
        venues_list.append([(
            cdn,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    # add the venues in the dataframe
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [
                        'CDN',
                        'Area Latitude', 
                        'Area Longitude', 
                        'Venue', 
                        'Venue Latitude', 
                        'Venue Longitude', 
                        'Venue Category'
    ]
    
    return(nearby_venues)

# %% [markdown]
# #### 1/ Best spots for opening a new chinese restaurant

# %% [markdown]
# As we just saw, the city areas with the most concentration of chinese people are the ones which have beed categorised into the **clusters 1 and 3**.
# These clusters represent the areas at the **north east of Toronto**.
#
# Because there are a lot of possible neighbourhoods, we are going to use FoursquareAPI to see the number of chinese restaurants that already exist in each city area. We will assume that the areas with the fewer number of existing chinese restaurants within these clusters will represent the best areas to open a new chinese restaurant

# %%
toronto_chinese = toronto_merged[(toronto_merged['Cluster Labels'] == 3) | (toronto_merged['Cluster Labels'] == 1)]

toronto_chinese.head()
# Out:
#    CDN                     City_Area  Latitude  Longitude  Cluster Labels  \
# 0  129               Agincourt North  43.80930  -79.26707               3
# 1  128  Agincourt South-Malvern West  43.78735  -79.26941               3
# 4   42             Banbury-Don Mills  43.74041  -79.34852               1
# 6   76           Bay Street Corridor  43.65771  -79.38618               1
# 7   52               Bayview Village  43.77710  -79.37957               1
#
#   1st Most Common Origin 2nd Most Common Origin 3rd Most Common Origin  \
# 0                Chinese             Sri Lankan            East Indian
# 1                Chinese            East Indian               Filipino
# 4                Chinese                English                  Irish
# 6                Chinese                English               Canadian
# 7                Chinese                Iranian                 Korean
#
#   4th Most Common Origin 5th Most Common Origin 6th Most Common Origin  \
# 0               Filipino               Canadian                English
# 1             Sri Lankan               Canadian                English
# 4               Canadian               Scottish            East Indian
# 6               Scottish                  Irish            East Indian
# 7                English               Canadian                  Irish
#
#   7th Most Common Origin 8th Most Common Origin 9th Most Common Origin  \
# 0                  Tamil               Jamaican               Scottish
# 1               Scottish               Jamaican                Italian
# 4                 German               Filipino                 Polish
# 6                 Korean                 German                 French
# 7               Scottish            East Indian               Filipino
#
#   10th Most Common Origin
# 0                   Irish
# 1                   Irish
# 4                  French
# 6                 Italian
# 7                  Polish

# %%
# Get the venues for each neighbourhood
chinese_restaurants_venues = getNearbyVenues(  
                                    cdn=toronto_chinese['CDN'],
                                    latitudes=toronto_chinese['Latitude'],
                                    longitudes=toronto_chinese['Longitude']
                                  )

chinese_restaurants_venues[(chinese_restaurants_venues['Venue Category'] == "Chinese Restaurant")].head()
# Out:
#     CDN  Area Latitude  Area Longitude                              Venue  \
# 8   129       43.80930       -79.26707                   Congee Town 太皇名粥
# 36  128       43.78735       -79.26941           Maple Yip Seafood 陸羽海鮮酒家
# 38  128       43.78735       -79.26941                   Asian Legend 味香村
# 43  128       43.78735       -79.26941                 Dumpling House 餃子莊
# 45  128       43.78735       -79.26941  Perfect Chinese Restaurant 雅瓊海鮮酒家
#
#     Venue Latitude  Venue Longitude      Venue Category
# 8        43.809035       -79.267634  Chinese Restaurant
# 36       43.784752       -79.277787  Chinese Restaurant
# 38       43.788068       -79.266768  Chinese Restaurant
# 43       43.787209       -79.269909  Chinese Restaurant
# 45       43.787774       -79.270294  Chinese Restaurant

# %%
chinese_restaurants_count = chinese_restaurants_venues.groupby(['CDN','Area Latitude', 'Area Longitude']).count().reset_index()

# Drop the useless columns
chinese_restaurants_count = chinese_restaurants_count.drop(chinese_restaurants_count.columns[[1,2,3,4,5]], axis=1)
chinese_restaurants_count.columns = ['CDN', 'Count']

# Merge the counts with the toronto_chinese dataframe
toronto_chinese = toronto_chinese.join(chinese_restaurants_count.set_index(['CDN']), on=['CDN'])
toronto_chinese = toronto_chinese.sort_values(by='Count')

toronto_chinese.head(15)
# Out:
#      CDN               City_Area  Latitude  Longitude  Cluster Labels  \
# 130   37         Willowdale West  43.77094  -79.42785               1
# 111   40    St.Andrew-Windfields  43.75720  -79.38188               1
# 86    36        Newtonbrook West  43.78818  -79.43173               1
# 8     49   Bayview Woods-Steeles  43.79485  -79.38220               1
# 98    46           Pleasant View  43.78812  -79.33453               1
# 76   130                Milliken  43.82280  -79.27694               3
# 112  116                 Steeles  43.81219  -79.32128               3
# 11   127                 Bendale  43.75963  -79.25739               1
# 85    50        Newtonbrook East  43.79304  -79.40695               1
# 52    48       Hillcrest Village  43.80303  -79.35346               1
# 129   51         Willowdale East  43.77248  -79.40039               3
# 66   117              L'Amoreaux  43.79726  -79.31220               3
# 31   126             Dorset Park  43.75533  -79.27746               1
# 114  118  Tam O'Shanter-Sullivan  43.78203  -79.30540               1
# 7     52         Bayview Village  43.77710  -79.37957               1
#
#     1st Most Common Origin 2nd Most Common Origin 3rd Most Common Origin  \
# 130                Chinese                 Korean                Iranian
# 111                Chinese                English               Canadian
# 86                Filipino                Chinese                Russian
# 8                  Chinese                Iranian                English
# 98                 Chinese                  Greek                Italian
# 76                 Chinese             Sri Lankan            East Indian
# 112                Chinese            East Indian               Canadian
# 11                 Chinese            East Indian               Filipino
# 85                 Chinese                Iranian                 Korean
# 52                 Chinese            East Indian               Canadian
# 129                Chinese                Iranian                 Korean
# 66                 Chinese            East Indian               Canadian
# 31                Filipino            East Indian                Chinese
# 114                Chinese            East Indian               Filipino
# 7                  Chinese                Iranian                 Korean
#
#     4th Most Common Origin 5th Most Common Origin 6th Most Common Origin  \
# 130                English               Canadian                  Irish
# 111                Iranian                 Polish                  Irish
# 86                  Korean                Iranian                 Jewish
# 8                 Canadian                 Korean                 Polish
# 98                Canadian            East Indian                English
# 76                Filipino               Canadian                  Tamil
# 112               Filipino                English                  Greek
# 11                Canadian                English               Scottish
# 85                 English               Canadian                  Irish
# 52                 Iranian                 Korean                English
# 129            East Indian                English               Canadian
# 66              Sri Lankan               Filipino                English
# 31                Canadian             Sri Lankan                English
# 114               Canadian                English                  Irish
# 7                  English               Canadian                  Irish
#
#     7th Most Common Origin 8th Most Common Origin 9th Most Common Origin  \
# 130               Scottish                Russian                Italian
# 111               Scottish                Russian            East Indian
# 86                 Italian              Ukrainian                English
# 8                    Irish               Scottish                Russian
# 98                Scottish               Filipino                  Irish
# 76                Jamaican                English             Vietnamese
# 112                Italian               Scottish             Sri Lankan
# 11                   Irish             Sri Lankan                  Greek
# 85                Scottish                Italian            East Indian
# 52                 Russian               Scottish                 Polish
# 129               Scottish                  Irish                Russian
# 66                Armenian               Jamaican               Scottish
# 31                Jamaican               Scottish                  Tamil
# 114               Scottish             Sri Lankan                  Greek
# 7                 Scottish            East Indian               Filipino
#
#     10th Most Common Origin  Count
# 130             East Indian      5
# 111                  Korean      5
# 86                 Canadian     14
# 8               East Indian     14
# 98                  Iranian     16
# 76                  Spanish     17
# 112                Egyptian     18
# 11                   French     18
# 85                 Filipino     19
# 52                    Irish     22
# 129                 Italian     23
# 66                    Irish     23
# 31                    Irish     24
# 114                Jamaican     24
# 7                    Polish     27

# %% [markdown]
# Draw the top 5 spots on the map

# %%
toronto_chinese_top = toronto_chinese.head(5)

# create map of Toronto using latitude and longitude values
spots_chinese_restaurants = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=11)

# add markers to map
for lat, lng, CDN, City_Area in zip(toronto_chinese_top['Latitude'], toronto_chinese_top['Longitude'], toronto_chinese_top['CDN'], toronto_chinese_top['City_Area']):
    label = '{} - {}'.format(CDN, City_Area)
    label = folium.Popup(label, parse_html=True)

    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(spots_chinese_restaurants) 
    
spots_chinese_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2/ Best spots for opening a new irish pub

# %% [markdown]
# The city areas with the most concentration of irish, scottish and english people are the ones which have beed categorised into the **clusters 4**.
# These clusters represent the areas in **the south and the downtown of Toronto**.
#
# Just like the chinese restaurants, we are going to use FoursquareAPI and assume that the areas with the fewer number of existing irish pubs will represent the best areas to open a new irish pub.

# %%
toronto_irish = toronto_merged[(toronto_merged['Cluster Labels'] == 4)]

toronto_irish.head()
# Out:
#     CDN                            City_Area  Latitude  Longitude  \
# 3    95                                Annex  43.66936  -79.40280
# 12  122                Birchcliffe-Cliffside  43.69472  -79.26460
# 23   75                Church-Yonge Corridor  43.66024  -79.37868
# 32   93  Dovercourt-Wallace Emerson-Junction  43.66604  -79.43687
# 35   62                    East End-Danforth  43.68415  -79.29911
#
#     Cluster Labels 1st Most Common Origin 2nd Most Common Origin  \
# 3                4                English                  Irish
# 12               4                English                  Irish
# 23               4                English                  Irish
# 32               4             Portuguese                English
# 35               4                English                  Irish
#
#    3rd Most Common Origin 4th Most Common Origin 5th Most Common Origin  \
# 3                Scottish               Canadian                 German
# 12               Canadian               Scottish                 French
# 23               Scottish                Chinese               Canadian
# 32               Canadian                  Irish               Scottish
# 35               Scottish               Canadian                 French
#
#    6th Most Common Origin 7th Most Common Origin 8th Most Common Origin  \
# 3                  French                 Polish                Chinese
# 12                 German                Chinese                Italian
# 23                 French                 German            East Indian
# 32                Chinese                Italian                 German
# 35                 German                Chinese                Italian
#
#    9th Most Common Origin              10th Most Common Origin
# 3                 Italian                              Russian
# 12               Filipino        British Isles origins; n.i.e.
# 23                Italian                               Polish
# 32                 French                          East Indian
# 35                 Polish        British Isles origins; n.i.e.

# %%
# Get the venues for each neighbourhood
irish_pubs_venues = getNearbyVenues(  
                                    cdn=toronto_irish['CDN'],
                                    latitudes=toronto_irish['Latitude'],
                                    longitudes=toronto_irish['Longitude']
                                  )

irish_pubs_venues[(irish_pubs_venues['Venue Category'] == "Pub")].head()
# Out:
#     CDN  Area Latitude  Area Longitude                   Venue  \
# 1    95       43.66936       -79.40280  The Madison Avenue Pub
# 58   95       43.66936       -79.40280            Duke of York
# 158  75       43.66024       -79.37868    Churchmouse & Firkin
# 336  62       43.68415       -79.29911     Grover Pub and Grub
# 371  62       43.68415       -79.29911       Mullins Irish Pub
#
#      Venue Latitude  Venue Longitude Venue Category
# 1         43.667947       -79.403486            Pub
# 58        43.669186       -79.397527            Pub
# 158       43.664632       -79.380406            Pub
# 336       43.679181       -79.297215            Pub
# 371       43.680348       -79.289370            Pub

# %%
irish_pubs_count = irish_pubs_venues.groupby(['CDN','Area Latitude', 'Area Longitude']).count().reset_index()

# Drop the useless columns
irish_pubs_count = irish_pubs_count.drop(irish_pubs_count.columns[[1,2,3,4,5]], axis=1)
irish_pubs_count.columns = ['CDN', 'Count']

# Merge the counts with the toronto_chinese dataframe
toronto_irish = toronto_irish.join(irish_pubs_count.set_index(['CDN']), on=['CDN'])
toronto_irish = toronto_irish.sort_values(by='Count')

toronto_irish.head(15)
# Out:
#      CDN                            City_Area  Latitude  Longitude  \
# 113   16                  Stonegate-Queensway  43.63718  -79.50058
# 12   122                Birchcliffe-Cliffside  43.69472  -79.26460
# 95    45                    Parkwoods-Donalda  43.75613  -79.32880
# 110   70                      South Riverdale  43.65221  -79.33820
# 77    17  Mimico (includes Humber Bay Shores)  43.61729  -79.49885
# 69   103                  Lawrence Park South  43.71853  -79.40574
# 58    14           Islington-City Centre West  43.63608  -79.54296
# 104   98                  Rosedale-Moore Park  43.68191  -79.37937
# 70    56                   Leaside-Bennington  43.70071  -79.36758
# 50    87                    High Park-Swansea  43.64704  -79.47114
# 83   104                  Mount Pleasant West  43.70541  -79.39256
# 35    62                    East End-Danforth  43.68415  -79.29911
# 68   105                  Lawrence Park North  43.72830  -79.40642
# 49    88                      High Park North  43.65767  -79.46458
# 116   63                          The Beaches  43.67413  -79.29644
#
#      Cluster Labels 1st Most Common Origin 2nd Most Common Origin  \
# 113               4                English               Canadian
# 12                4                English                  Irish
# 95                4               Canadian                English
# 110               4                Chinese                English
# 77                4                English               Canadian
# 69                4                English               Scottish
# 58                4                English               Canadian
# 104               4                English               Scottish
# 70                4                English               Scottish
# 50                4                English                  Irish
# 83                4                English               Scottish
# 35                4                English                  Irish
# 68                4                English               Scottish
# 49                4                English                  Irish
# 116               4                English                  Irish
#
#     3rd Most Common Origin 4th Most Common Origin 5th Most Common Origin  \
# 113                  Irish               Scottish                 Polish
# 12                Canadian               Scottish                 French
# 95                 Chinese               Scottish                  Irish
# 110                  Irish               Scottish               Canadian
# 77                   Irish               Scottish                Italian
# 69                Canadian                  Irish                 German
# 58                 Italian                  Irish               Scottish
# 104                  Irish               Canadian                 German
# 70                   Irish               Canadian                 German
# 50                Scottish               Canadian                 German
# 83                Canadian                  Irish                 German
# 35                Scottish               Canadian                 French
# 68                Canadian                  Irish                 German
# 49                Scottish               Canadian                 German
# 116               Scottish               Canadian                 French
#
#     6th Most Common Origin 7th Most Common Origin 8th Most Common Origin  \
# 113                Italian              Ukrainian                 German
# 12                  German                Chinese                Italian
# 95                Filipino            East Indian                 German
# 110                 French                 German                Italian
# 77                  Polish              Ukrainian                 German
# 69                  Polish                Russian                 French
# 58                  Polish              Ukrainian            East Indian
# 104                 French                Chinese                 Polish
# 70                  French                Italian                Chinese
# 50                  Polish                 French                Italian
# 83                  French                 Polish                Russian
# 35                  German                Chinese                Italian
# 68                 Chinese                 French                 Polish
# 49                  Polish                 French              Ukrainian
# 116                 German                Italian                 Polish
#
#                   9th Most Common Origin              10th Most Common Origin  \
# 113                               French                           Portuguese
# 12                              Filipino        British Isles origins; n.i.e.
# 95                              Jamaican                               French
# 110        British Isles origins; n.i.e.                               Polish
# 77                                French                              Chinese
# 69                               Italian                              Chinese
# 58                                German                              Chinese
# 104                              Italian        British Isles origins; n.i.e.
# 70         British Isles origins; n.i.e.                               Polish
# 50                             Ukrainian        British Isles origins; n.i.e.
# 83                           East Indian                              Chinese
# 35                                Polish        British Isles origins; n.i.e.
# 68                               Italian                              Russian
# 49                               Italian                              Russian
# 116        British Isles origins; n.i.e.                                Dutch
#
#      Count
# 113      4
# 12      16
# 95      23
# 110     31
# 77      31
# 69      39
# 58      44
# 104     44
# 70      60
# 50      62
# 83      65
# 35      66
# 68      79
# 49      88
# 116     92

# %% [markdown]
# Draw the top 5 on the map

# %%
toronto_pubs_top = toronto_irish.head(5)

# create map of Toronto using latitude and longitude values
spots_irish_pubs = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=11)

# add markers to map
for lat, lng, CDN, City_Area in zip(toronto_pubs_top['Latitude'], toronto_pubs_top['Longitude'], toronto_pubs_top['CDN'], toronto_pubs_top['City_Area']):
    label = '{} - {}'.format(CDN, City_Area)
    label = folium.Popup(label, parse_html=True)

    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(spots_irish_pubs) 
    
spots_irish_pubs
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
